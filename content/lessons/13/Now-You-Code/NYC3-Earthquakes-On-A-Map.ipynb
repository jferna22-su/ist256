# %% [markdown]
# ## Now You Code 3: Mapping Earthquakes
#
# Let's plot a live map of earthquakes from the USGS earthquake data feed.
#
# Here's a sample of the output, zoomed in over California
#
# ![NYC3-screenshot.png](NYC3-screenshot.png)
#
# How to do it:
#
# - Read the earthquake data from http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_week.geojson
# - Then plot it on a folium map using CircleMarkers (no need to use Pandas).
# - Make the size of the marker correlate to the magnitude of the earthquake (bigger circle for bigger magnitude) also when you click on the marker you should see the title of the earthquake.
#
# Here's a formula for making your markers more noticeable:
# `radius = ( 75 * earthquake_magnitude) ** 2` Feel free to tweak the formula.

# %% [markdown]
# ## Step 1: Problem Analysis
#
# Inputs:
#
# Outputs:
#
# Algorithm (Steps in Program):

# %%
# Step 2: Write your code here
import pandas as pd
import folium
from urllib.request import urlopen
import json

us_map = (39.8333333,-98.585522)
map = folium.Map(location=us_map, zoom_start=4)


url = "https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_week.geojson"
response = urlopen(url)
data = json.loads(response.read())
(data)
# Out:
# {'type': 'FeatureCollection',
#  'metadata': {'generated': 1575665259000,
#   'url': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/1.0_week.geojson',
#   'title': 'USGS Magnitude 1.0+ Earthquakes, Past Week',
#   'status': 200,
#   'api': '1.8.1',
#   'count': 1314},
#  'features': [{'type': 'Feature',
#    'properties': {'mag': 1.85,
#     'place': '22km NE of San Lucas, CA',
#     'time': 1575665143440,
#     'updated': 1575665241720,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73312261',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73312261.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 53,
#     'net': 'nc',
#     'code': '73312261',
#     'ids': ',nc73312261,',
#     'sources': ',nc,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,',
#     'nst': 10,
#     'dmin': 0.07148,
#     'rms': 0.05,
#     'gap': 208,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 22km NE of San Lucas, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-120.8738327, 36.2901649, 7.94]},
#    'id': 'nc73312261'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.6,
#     'place': '17km S of Agrihan, Northern Mariana Islands',
#     'time': 1575664217875,
#     'updated': 1575665241040,
#     'tz': 600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us60006n8n',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us60006n8n.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 326,
#     'net': 'us',
#     'code': '60006n8n',
#     'ids': ',us60006n8n,',
#     'sources': ',us,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': 3.355,
#     'rms': 1.03,
#     'gap': 79,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.6 - 17km S of Agrihan, Northern Mariana Islands'},
#    'geometry': {'type': 'Point', 'coordinates': [145.6624, 18.6131, 159.87]},
#    'id': 'us60006n8n'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.2,
#     'place': '11km E of Eielson Air Force Base, Alaska',
#     'time': 1575663696558,
#     'updated': 1575664129906,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019fmmr8to',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019fmmr8to.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 22,
#     'net': 'ak',
#     'code': '019fmmr8to',
#     'ids': ',ak019fmmr8to,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.36,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 11km E of Eielson Air Force Base, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-146.8241, 64.6545, 8.1]},
#    'id': 'ak019fmmr8to'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.19,
#     'place': '14km SE of Volcano, Hawaii',
#     'time': 1575662873300,
#     'updated': 1575663216780,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv71265386',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv71265386.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 74,
#     'net': 'hv',
#     'code': '71265386',
#     'ids': ',hv71265386,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 47,
#     'dmin': 0.04833,
#     'rms': 0.17,
#     'gap': 125,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 14km SE of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.1401672, 19.3383331, 3.46]},
#    'id': 'hv71265386'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '29km WNW of Yonakuni, Japan',
#     'time': 1575660752753,
#     'updated': 1575664044040,
#     'tz': 480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us60006n83',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us60006n83.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 312,
#     'net': 'us',
#     'code': '60006n83',
#     'ids': ',us60006n83,',
#     'sources': ',us,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': 0.275,
#     'rms': 0.7,
#     'gap': 52,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 29km WNW of Yonakuni, Japan'},
#    'geometry': {'type': 'Point', 'coordinates': [122.7425, 24.5936, 95.14]},
#    'id': 'us60006n83'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.14,
#     'place': '5km NNW of Lake Elsinore, CA',
#     'time': 1575660703820,
#     'updated': 1575660933320,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39219984',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39219984.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 20,
#     'net': 'ci',
#     'code': '39219984',
#     'ids': ',ci39219984,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 22,
#     'dmin': 0.04209,
#     'rms': 0.18,
#     'gap': 105,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 5km NNW of Lake Elsinore, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.3445, 33.7141667, 1.58]},
#    'id': 'ci39219984'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.07,
#     'place': '21km ENE of Honaunau-Napoopoo, Hawaii',
#     'time': 1575660525110,
#     'updated': 1575660870450,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv71265366',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv71265366.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 66,
#     'net': 'hv',
#     'code': '71265366',
#     'ids': ',hv71265366,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 32,
#     'dmin': 0.0373,
#     'rms': 0.3,
#     'gap': 81,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.1 - 21km ENE of Honaunau-Napoopoo, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.6633301, 19.5013332, -1.92]},
#    'id': 'hv71265366'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.8,
#     'place': '32km NNE of Yakutat, Alaska',
#     'time': 1575660126473,
#     'updated': 1575660424607,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019fmm5ynb',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019fmm5ynb.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 50,
#     'net': 'ak',
#     'code': '019fmm5ynb',
#     'ids': ',ak019fmm5ynb,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 1.2,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 32km NNE of Yakutat, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-139.5717, 59.8288, 0]},
#    'id': 'ak019fmm5ynb'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.9,
#     'place': '32km W of Big Lake, Alaska',
#     'time': 1575659855574,
#     'updated': 1575660042366,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019fmm4yb9',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019fmm4yb9.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 56,
#     'net': 'ak',
#     'code': '019fmm4yb9',
#     'ids': ',ak019fmm4yb9,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.46,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 32km W of Big Lake, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-150.5638, 61.533, 49.6]},
#    'id': 'ak019fmm4yb9'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.25,
#     'place': '16km S of Trona, CA',
#     'time': 1575659786110,
#     'updated': 1575660011110,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39219960',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39219960.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 24,
#     'net': 'ci',
#     'code': '39219960',
#     'ids': ',ci39219960,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 15,
#     'dmin': 0.06313,
#     'rms': 0.14,
#     'gap': 88,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 16km S of Trona, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.3936667, 35.616, 2.82]},
#    'id': 'ci39219960'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.35,
#     'place': '10km NE of Coso Junction, CA',
#     'time': 1575659724370,
#     'updated': 1575659935089,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39219952',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39219952.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 28,
#     'net': 'ci',
#     'code': '39219952',
#     'ids': ',ci39219952,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 12,
#     'dmin': 0.01705,
#     'rms': 0.06,
#     'gap': 81,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 10km NE of Coso Junction, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.8543333, 36.1005, 3.51]},
#    'id': 'ci39219952'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.41,
#     'place': '14km NE of Ridgecrest, CA',
#     'time': 1575658213790,
#     'updated': 1575658435832,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39219920',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39219920.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 31,
#     'net': 'ci',
#     'code': '39219920',
#     'ids': ',ci39219920,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 25,
#     'dmin': 0.09575,
#     'rms': 0.21,
#     'gap': 65,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 14km NE of Ridgecrest, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.5753333, 35.7215, 11.12]},
#    'id': 'ci39219920'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.23,
#     'place': '10km NE of Ridgecrest, CA',
#     'time': 1575658148070,
#     'updated': 1575658825590,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39219912',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39219912.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 77,
#     'net': 'ci',
#     'code': '39219912',
#     'ids': ',ci39219912,',
#     'sources': ',ci,',
#     'types': ',focal-mechanism,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 32,
#     'dmin': 0.07924,
#     'rms': 0.15,
#     'gap': 58,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 10km NE of Ridgecrest, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.6098333, 35.6941667, 7.3]},
#    'id': 'ci39219912'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '7km S of Talkeetna, Alaska',
#     'time': 1575657708301,
#     'updated': 1575658012704,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019fmloovk',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019fmloovk.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'ak',
#     'code': '019fmloovk',
#     'ids': ',ak019fmloovk,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.59,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 7km S of Talkeetna, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-150.1268, 62.2526, 6]},
#    'id': 'ak019fmloovk'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.11,
#     'place': '22km N of Yucca Valley, CA',
#     'time': 1575655702700,
#     'updated': 1575655927057,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39219872',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39219872.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 19,
#     'net': 'ci',
#     'code': '39219872',
#     'ids': ',ci39219872,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 13,
#     'dmin': 0.06264,
#     'rms': 0.13,
#     'gap': 170,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 22km N of Yucca Valley, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.454, 34.3121667, 9.53]},
#    'id': 'ci39219872'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.26,
#     'place': '11km NE of Coso Junction, CA',
#     'time': 1575655540540,
#     'updated': 1575655753099,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39219856',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39219856.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 24,
#     'net': 'ci',
#     'code': '39219856',
#     'ids': ',ci39219856,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 11,
#     'dmin': 0.01578,
#     'rms': 0.09,
#     'gap': 121,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 11km NE of Coso Junction, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.8505, 36.1021667, 3.16]},
#    'id': 'ci39219856'},
#   {'type': 'Feature',
#    'properties': {'mag': 2,
#     'place': '18km NNW of Anchorage, Alaska',
#     'time': 1575655532930,
#     'updated': 1575656066487,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019fmlgxwp',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019fmlgxwp.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 62,
#     'net': 'ak',
#     'code': '019fmlgxwp',
#     'ids': ',ak019fmlgxwp,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.53,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 18km NNW of Anchorage, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-150.0532, 61.3622, 33.1]},
#    'id': 'ak019fmlgxwp'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.95,
#     'place': '32km WNW of Petrolia, CA',
#     'time': 1575655475090,
#     'updated': 1575660584362,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73312236',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73312236.geojson',
#     'felt': 1,
#     'cdi': 2,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 134,
#     'net': 'nc',
#     'code': '73312236',
#     'ids': ',nc73312236,',
#     'sources': ',nc,',
#     'types': ',dyfi,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 24,
#     'dmin': 0.262,
#     'rms': 0.12,
#     'gap': 258,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 3.0 - 32km WNW of Petrolia, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-124.6443329, 40.4129982, 19.79]},
#    'id': 'nc73312236'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.84,
#     'place': '6km WSW of Volcano, Hawaii',
#     'time': 1575655461340,
#     'updated': 1575657998040,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv71265261',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv71265261.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 124,
#     'net': 'hv',
#     'code': '71265261',
#     'ids': ',hv71265261,us60006n5h,',
#     'sources': ',hv,us,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 27,
#     'dmin': 0.01581,
#     'rms': 0.34,
#     'gap': 53,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 6km WSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2878265, 19.4021664, -0.61]},
#    'id': 'hv71265261'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.83,
#     'place': '6km WSW of Volcano, Hawaii',
#     'time': 1575655460030,
#     'updated': 1575655800970,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv71265256',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv71265256.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 123,
#     'net': 'hv',
#     'code': '71265256',
#     'ids': ',hv71265256,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 29,
#     'dmin': 0.01026,
#     'rms': 0.22,
#     'gap': 44,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.8 - 6km WSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2913361, 19.3999996, 0.87]},
#    'id': 'hv71265256'},
#   {'type': 'Feature',
#    'properties': {'mag': 1,
#     'place': '46km N of Ester, Alaska',
#     'time': 1575654395647,
#     'updated': 1575654855904,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019fml4auw',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019fml4auw.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 15,
#     'net': 'ak',
#     'code': '019fml4auw',
#     'ids': ',ak019fml4auw,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.36,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.0 - 46km N of Ester, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-148.1953, 65.2556, 2.9]},
#    'id': 'ak019fml4auw'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.67,
#     'place': '11km SSW of Searles Valley, CA',
#     'time': 1575653772430,
#     'updated': 1575654427490,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39219816',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39219816.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 43,
#     'net': 'ci',
#     'code': '39219816',
#     'ids': ',ci39219816,',
#     'sources': ',ci,',
#     'types': ',focal-mechanism,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 24,
#     'dmin': 0.08518,
#     'rms': 0.19,
#     'gap': 87,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 11km SSW of Searles Valley, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.4668333, 35.6823333, 1.22]},
#    'id': 'ci39219816'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.5,
#     'place': '16km S of Trona, CA',
#     'time': 1575653649150,
#     'updated': 1575653884780,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39219808',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39219808.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 35,
#     'net': 'ci',
#     'code': '39219808',
#     'ids': ',ci39219808,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 25,
#     'dmin': 0.0561,
#     'rms': 0.19,
#     'gap': 110,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 16km S of Trona, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.4061667, 35.6191667, 3.21]},
#    'id': 'ci39219808'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.14,
#     'place': '2km ENE of Brea, CA',
#     'time': 1575653237390,
#     'updated': 1575656135017,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39219784',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39219784.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 20,
#     'net': 'ci',
#     'code': '39219784',
#     'ids': ',ci39219784,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 19,
#     'dmin': 0.04389,
#     'rms': 0.22,
#     'gap': 166,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 2km ENE of Brea, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.879, 33.922, 6.8]},
#    'id': 'ci39219784'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.1,
#     'place': '21km E of Little Lake, CA',
#     'time': 1575653214020,
#     'updated': 1575653430730,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39219776',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39219776.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 19,
#     'net': 'ci',
#     'code': '39219776',
#     'ids': ',ci39219776,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 18,
#     'dmin': 0.02936,
#     'rms': 0.13,
#     'gap': 60,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 21km E of Little Lake, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.6693333, 35.9228333, 1.68]},
#    'id': 'ci39219776'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.55,
#     'place': '3km SE of Frazier Park, CA',
#     'time': 1575652805880,
#     'updated': 1575653044689,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39219768',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39219768.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 37,
#     'net': 'ci',
#     'code': '39219768',
#     'ids': ',ci39219768,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 22,
#     'dmin': 0.04418,
#     'rms': 0.21,
#     'gap': 68,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 3km SE of Frazier Park, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.921, 34.802, 13.89]},
#    'id': 'ci39219768'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.84,
#     'place': '9km S of Emajagua, Puerto Rico',
#     'time': 1575652660820,
#     'updated': 1575660715406,
#     'tz': -240,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019340012',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2019340012.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 52,
#     'net': 'pr',
#     'code': '2019340012',
#     'ids': ',pr2019340012,',
#     'sources': ',pr,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 4,
#     'dmin': 0.235,
#     'rms': 0.14,
#     'gap': 299,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 9km S of Emajagua, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-65.896, 17.9118, 6]},
#    'id': 'pr2019340012'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.01,
#     'place': '25km SW of Ocotillo Wells, CA',
#     'time': 1575652505590,
#     'updated': 1575652714712,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39219760',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39219760.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 16,
#     'net': 'ci',
#     'code': '39219760',
#     'ids': ',ci39219760,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 19,
#     'dmin': 0.01546,
#     'rms': 0.18,
#     'gap': 78,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.0 - 25km SW of Ocotillo Wells, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-116.285, 32.954, 9.98]},
#    'id': 'ci39219760'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.56,
#     'place': '5km SSE of Home Gardens, CA',
#     'time': 1575652038940,
#     'updated': 1575652270609,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39219736',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39219736.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 37,
#     'net': 'ci',
#     'code': '39219736',
#     'ids': ',ci39219736,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 45,
#     'dmin': 0.04971,
#     'rms': 0.18,
#     'gap': 46,
#     'magType': 'ml',
#     'type': 'quarry blast',
#     'title': 'M 1.6 Quarry Blast - 5km SSE of Home Gardens, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.4998333, 33.8371667, 1.88]},
#    'id': 'ci39219736'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.2,
#     'place': '10km S of Salton City, CA',
#     'time': 1575650741210,
#     'updated': 1575650982949,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39219688',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39219688.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 74,
#     'net': 'ci',
#     'code': '39219688',
#     'ids': ',ci39219688,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 55,
#     'dmin': 0.1519,
#     'rms': 0.23,
#     'gap': 36,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 10km S of Salton City, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-115.9641667, 33.2116667, 2.54]},
#    'id': 'ci39219688'},
#   {'type': 'Feature',
#    'properties': {'mag': 2,
#     'place': '50km N of Valdez, Alaska',
#     'time': 1575650409087,
#     'updated': 1575650970822,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019fmkhixj',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019fmkhixj.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 62,
#     'net': 'ak',
#     'code': '019fmkhixj',
#     'ids': ',ak019fmkhixj,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.8,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 50km N of Valdez, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-146.4261, 61.5843, 23.7]},
#    'id': 'ak019fmkhixj'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '9km SSE of Big Lake, Alaska',
#     'time': 1575650016638,
#     'updated': 1575650637801,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019fmkg31b',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019fmkg31b.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'ak',
#     'code': '019fmkg31b',
#     'ids': ',ak019fmkg31b,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.43,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 9km SSE of Big Lake, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.8771, 61.4408, 34.2]},
#    'id': 'ak019fmkg31b'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.86,
#     'place': '14km S of Volcano, Hawaii',
#     'time': 1575649916690,
#     'updated': 1575650257050,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv71265126',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv71265126.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 53,
#     'net': 'hv',
#     'code': '71265126',
#     'ids': ',hv71265126,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 40,
#     'dmin': 0.02451,
#     'rms': 0.13,
#     'gap': 141,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 14km S of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2151642, 19.3041668, 2.22]},
#    'id': 'hv71265126'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.73,
#     'place': '11km S of Tres Pinos, CA',
#     'time': 1575649800120,
#     'updated': 1575653630401,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73312226',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73312226.geojson',
#     'felt': 1,
#     'cdi': 2.2,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 115,
#     'net': 'nc',
#     'code': '73312226',
#     'ids': ',nc73312226,',
#     'sources': ',nc,',
#     'types': ',dyfi,focal-mechanism,geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 28,
#     'dmin': 0.04804,
#     'rms': 0.09,
#     'gap': 106,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 11km S of Tres Pinos, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-121.315834, 36.6901665, -0.06]},
#    'id': 'nc73312226'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '42km WNW of Valdez, Alaska',
#     'time': 1575649766412,
#     'updated': 1575650637455,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019fmkf7dt',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019fmkf7dt.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'ak',
#     'code': '019fmkf7dt',
#     'ids': ',ak019fmkf7dt,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.73,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 42km WNW of Valdez, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-147.1171, 61.2174, 17.5]},
#    'id': 'ak019fmkf7dt'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.8,
#     'place': '5km WSW of Volcano, Hawaii',
#     'time': 1575649512380,
#     'updated': 1575649694940,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv71265111',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv71265111.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 50,
#     'net': 'hv',
#     'code': '71265111',
#     'ids': ',hv71265111,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 21,
#     'dmin': 0.00551,
#     'rms': 0.09,
#     'gap': 69,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 5km WSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2875061, 19.413166, 0.62]},
#    'id': 'hv71265111'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '64km NNE of Talkeetna, Alaska',
#     'time': 1575648628372,
#     'updated': 1575648909513,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019fmkb4yt',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019fmkb4yt.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'ak',
#     'code': '019fmkb4yt',
#     'ids': ',ak019fmkb4yt,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.36,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 64km NNE of Talkeetna, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.5502, 62.845, 76.2]},
#    'id': 'ak019fmkb4yt'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.98,
#     'place': '30km NNW of Searles Valley, CA',
#     'time': 1575648437810,
#     'updated': 1575648648716,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39219632',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39219632.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 15,
#     'net': 'ci',
#     'code': '39219632',
#     'ids': ',ci39219632,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 13,
#     'dmin': 0.06588,
#     'rms': 0.19,
#     'gap': 113,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.0 - 30km NNW of Searles Valley, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.5766667, 35.9985, 1.47]},
#    'id': 'ci39219632'},
#   {'type': 'Feature',
#    'properties': {'mag': 0.99,
#     'place': '15km WSW of Searles Valley, CA',
#     'time': 1575647418390,
#     'updated': 1575647644532,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39219616',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39219616.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 15,
#     'net': 'ci',
#     'code': '39219616',
#     'ids': ',ci39219616,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 15,
#     'dmin': 0.09767,
#     'rms': 0.24,
#     'gap': 128,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.0 - 15km WSW of Searles Valley, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.5603333, 35.7226667, 10.78]},
#    'id': 'ci39219616'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.11,
#     'place': '18km NNE of Kernville, CA',
#     'time': 1575647131050,
#     'updated': 1575647344590,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39219600',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39219600.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 19,
#     'net': 'ci',
#     'code': '39219600',
#     'ids': ',ci39219600,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 14,
#     'dmin': 0.2057,
#     'rms': 0.24,
#     'gap': 109,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 18km NNE of Kernville, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.3293333, 35.9005, 0.09]},
#    'id': 'ci39219600'},
#   {'type': 'Feature',
#    'properties': {'mag': 5.7,
#     'place': '173km NW of Hihifo, Tonga',
#     'time': 1575646964671,
#     'updated': 1575661053040,
#     'tz': -720,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us60006n2z',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us60006n2z.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': 3.858,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 500,
#     'net': 'us',
#     'code': '60006n2z',
#     'ids': ',pt19340001,us60006n2z,',
#     'sources': ',pt,us,',
#     'types': ',geoserve,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 3.384,
#     'rms': 0.6,
#     'gap': 44,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 5.7 - 173km NW of Hihifo, Tonga'},
#    'geometry': {'type': 'Point', 'coordinates': [-175.0727, -15.041, 10]},
#    'id': 'us60006n2z'},
#   {'type': 'Feature',
#    'properties': {'mag': 2,
#     'place': '15km ESE of Navarro Head, CA',
#     'time': 1575645548950,
#     'updated': 1575646743895,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73312221',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73312221.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 62,
#     'net': 'nc',
#     'code': '73312221',
#     'ids': ',nc73312221,',
#     'sources': ',nc,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 12,
#     'dmin': 0.05032,
#     'rms': 0.08,
#     'gap': 155,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.0 - 15km ESE of Navarro Head, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-123.600502, 39.158165, 5.45]},
#    'id': 'nc73312221'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '57km N of Pahrump, Nevada',
#     'time': 1575643365882,
#     'updated': 1575659078607,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nn00712492',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nn00712492.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'nn',
#     'code': '00712492',
#     'ids': ',nn00712492,',
#     'sources': ',nn,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 32,
#     'dmin': 0.099,
#     'rms': 0.1899,
#     'gap': 121.22,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 57km N of Pahrump, Nevada'},
#    'geometry': {'type': 'Point', 'coordinates': [-115.8622, 36.7193, 0]},
#    'id': 'nn00712492'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.5,
#     'place': '11km NE of Coso Junction, CA',
#     'time': 1575642918880,
#     'updated': 1575643156199,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39219520',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39219520.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 35,
#     'net': 'ci',
#     'code': '39219520',
#     'ids': ',ci39219520,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 13,
#     'dmin': 0.009031,
#     'rms': 0.14,
#     'gap': 145,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.5 - 11km NE of Coso Junction, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.852, 36.1088333, 3.84]},
#    'id': 'ci39219520'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.4,
#     'place': '2km ESE of Big Lake, Alaska',
#     'time': 1575642755759,
#     'updated': 1575642926966,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019fmj901j',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019fmj901j.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 30,
#     'net': 'ak',
#     'code': '019fmj901j',
#     'ids': ',ak019fmj901j,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.71,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 2km ESE of Big Lake, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-149.9051, 61.5164, 42.1]},
#    'id': 'ak019fmj901j'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.1,
#     'place': '14km ENE of Ridgecrest, CA',
#     'time': 1575642136300,
#     'updated': 1575642363734,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39219512',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39219512.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 19,
#     'net': 'ci',
#     'code': '39219512',
#     'ids': ',ci39219512,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 16,
#     'dmin': 0.06336,
#     'rms': 0.17,
#     'gap': 122,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 14km ENE of Ridgecrest, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.5473333, 35.683, 7.36]},
#    'id': 'ci39219512'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.6,
#     'place': '48km WNW of Willow, Alaska',
#     'time': 1575641672128,
#     'updated': 1575641952908,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019fmj54vo',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019fmj54vo.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'ak',
#     'code': '019fmj54vo',
#     'ids': ',ak019fmj54vo,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.29,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 48km WNW of Willow, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-150.868, 61.9375, 66.2]},
#    'id': 'ak019fmj54vo'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.73,
#     'place': '96km NNW of San Antonio, Puerto Rico',
#     'time': 1575637807890,
#     'updated': 1575654188517,
#     'tz': -240,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019340011',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2019340011.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 115,
#     'net': 'pr',
#     'code': '2019340011',
#     'ids': ',pr2019340011,',
#     'sources': ',pr,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 6,
#     'dmin': 0.8954,
#     'rms': 0.39,
#     'gap': 309,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.7 - 96km NNW of San Antonio, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-67.3893, 19.3186, 29]},
#    'id': 'pr2019340011'},
#   {'type': 'Feature',
#    'properties': {'mag': 6,
#     'place': '164km WNW of Hihifo, Tonga',
#     'time': 1575637486931,
#     'updated': 1575661159040,
#     'tz': -720,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us60006n19',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us60006n19.geojson',
#     'felt': 2,
#     'cdi': 2,
#     'mmi': 4.218,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 554,
#     'net': 'us',
#     'code': '60006n19',
#     'ids': ',us60006n19,pt19340000,',
#     'sources': ',us,pt,',
#     'types': ',dyfi,geoserve,ground-failure,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': 3.512,
#     'rms': 0.81,
#     'gap': 50,
#     'magType': 'mww',
#     'type': 'earthquake',
#     'title': 'M 6.0 - 164km WNW of Hihifo, Tonga'},
#    'geometry': {'type': 'Point', 'coordinates': [-175.1193, -15.2838, 10]},
#    'id': 'us60006n19'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.36,
#     'place': '8km E of Ridgecrest, CA',
#     'time': 1575637197000,
#     'updated': 1575637421208,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39219464',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39219464.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 28,
#     'net': 'ci',
#     'code': '39219464',
#     'ids': ',ci39219464,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 21,
#     'dmin': 0.01214,
#     'rms': 0.14,
#     'gap': 83,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 8km E of Ridgecrest, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.5838333, 35.6201667, 6.98]},
#    'id': 'ci39219464'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.55,
#     'place': '10km ESE of Olancha, CA',
#     'time': 1575636927340,
#     'updated': 1575639764552,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39219456',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39219456.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 37,
#     'net': 'ci',
#     'code': '39219456',
#     'ids': ',ci39219456,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 15,
#     'dmin': 0.1438,
#     'rms': 0.17,
#     'gap': 130,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 10km ESE of Olancha, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.891, 36.2586667, 0.81]},
#    'id': 'ci39219456'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.16,
#     'place': '20km WNW of Puerto Real, Puerto Rico',
#     'time': 1575636489820,
#     'updated': 1575652654359,
#     'tz': -240,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019340010',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2019340010.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 72,
#     'net': 'pr',
#     'code': '2019340010',
#     'ids': ',pr2019340010,',
#     'sources': ',pr,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 6,
#     'dmin': 0.286,
#     'rms': 0.19,
#     'gap': 226,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 20km WNW of Puerto Real, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-67.3748, 18.1136, 20]},
#    'id': 'pr2019340010'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.6,
#     'place': '117km NNW of Talkeetna, Alaska',
#     'time': 1575636088845,
#     'updated': 1575638348880,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019fmi41qy',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019fmi41qy.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'ak',
#     'code': '019fmi41qy',
#     'ids': ',ak019fmi41qy,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.82,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 117km NNW of Talkeetna, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.2683, 63.2365, 4.1]},
#    'id': 'ak019fmi41qy'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.39,
#     'place': '3km E of Prattville, CA',
#     'time': 1575635996420,
#     'updated': 1575655018791,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73312211',
# ...
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019fe8g7nl.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'ak',
#     'code': '019fe8g7nl',
#     'ids': ',ak019fe8g7nl,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.14,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 75km N of Larsen Bay, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-154.1465, 58.215, 72.5]},
#    'id': 'ak019fe8g7nl'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.27,
#     'place': '14km WNW of Kalaoa, Hawaii',
#     'time': 1575203619170,
#     'updated': 1575438023040,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv71257361',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv71257361.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 79,
#     'net': 'hv',
#     'code': '71257361',
#     'ids': ',hv71257361,us70006ffd,',
#     'sources': ',hv,us,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 48,
#     'dmin': 0.1436,
#     'rms': 0.13,
#     'gap': 266,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 2.3 - 14km WNW of Kalaoa, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-156.1181667, 19.7613333, 38]},
#    'id': 'hv71257361'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.5,
#     'place': '57km WSW of Anchor Point, Alaska',
#     'time': 1575203272736,
#     'updated': 1575359431686,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019fe8ccze',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019fe8ccze.geojson',
#     'felt': 42,
#     'cdi': 4.1,
#     'mmi': 2.78,
#     'alert': 'green',
#     'status': 'reviewed',
#     'tsunami': 1,
#     'sig': 329,
#     'net': 'ak',
#     'code': '019fe8ccze',
#     'ids': ',ak019fe8ccze,at00q1u2mf,us70006f07,',
#     'sources': ',ak,at,us,',
#     'types': ',dyfi,geoserve,impact-link,losspager,moment-tensor,origin,phase-data,shakemap,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.47,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 4.5 - 57km WSW of Anchor Point, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-152.7893, 59.6127, 89.2]},
#    'id': 'ak019fe8ccze'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.4,
#     'place': '34km WNW of Anchor Point, Alaska',
#     'time': 1575202768060,
#     'updated': 1575202926711,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019fe8algm',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019fe8algm.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 30,
#     'net': 'ak',
#     'code': '019fe8algm',
#     'ids': ',ak019fe8algm,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.33,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.4 - 34km WNW of Anchor Point, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-152.3757, 59.9177, 89.8]},
#    'id': 'ak019fe8algm'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.8,
#     'place': '12km SW of Stella, Puerto Rico',
#     'time': 1575201016930,
#     'updated': 1575216756545,
#     'tz': -240,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr2019335008',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/pr2019335008.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 50,
#     'net': 'pr',
#     'code': '2019335008',
#     'ids': ',pr2019335008,',
#     'sources': ',pr,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 4,
#     'dmin': 0.2678,
#     'rms': 0.8,
#     'gap': 303,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 12km SW of Stella, Puerto Rico'},
#    'geometry': {'type': 'Point', 'coordinates': [-67.3401, 18.2598, 18]},
#    'id': 'pr2019335008'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.25,
#     'place': '22km ESE of Little Lake, CA',
#     'time': 1575199635240,
#     'updated': 1575298243292,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39212936',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39212936.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 24,
#     'net': 'ci',
#     'code': '39212936',
#     'ids': ',ci39212936,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 23,
#     'dmin': 0.0819,
#     'rms': 0.12,
#     'gap': 48,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.3 - 22km ESE of Little Lake, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.6766667, 35.8686667, 8.82]},
#    'id': 'ci39212936'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.7,
#     'place': '18km N of Anchor Point, Alaska',
#     'time': 1575199531275,
#     'updated': 1575200057674,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019fe7qged',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019fe7qged.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 44,
#     'net': 'ak',
#     'code': '019fe7qged',
#     'ids': ',ak019fe7qged,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.71,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.7 - 18km N of Anchor Point, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-151.8701, 59.9412, 42.7]},
#    'id': 'ak019fe7qged'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.18,
#     'place': '28km NNE of Seeley Lake, Montana',
#     'time': 1575198872820,
#     'updated': 1575324661120,
#     'tz': -420,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/mb80373989',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/mb80373989.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 21,
#     'net': 'mb',
#     'code': '80373989',
#     'ids': ',mb80373989,',
#     'sources': ',mb,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 14,
#     'dmin': 0.195,
#     'rms': 0.15,
#     'gap': 181,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 28km NNE of Seeley Lake, Montana'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-113.3976667, 47.4258333, 15.64]},
#    'id': 'mb80373989'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.12,
#     'place': '39km N of Toms Place, CA',
#     'time': 1575198673020,
#     'updated': 1575529983535,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73310621',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73310621.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 19,
#     'net': 'nc',
#     'code': '73310621',
#     'ids': ',nn00712071,nc73310621,',
#     'sources': ',nn,nc,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 15,
#     'dmin': 0.2657,
#     'rms': 0.03,
#     'gap': 327,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.1 - 39km N of Toms Place, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-118.6553333, 37.9126667, 4.47]},
#    'id': 'nc73310621'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.9,
#     'place': '112km SW of Larsen Bay, Alaska',
#     'time': 1575198574196,
#     'updated': 1575198852884,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019fe7n163',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019fe7n163.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 56,
#     'net': 'ak',
#     'code': '019fe7n163',
#     'ids': ',ak019fe7n163,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.55,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.9 - 112km SW of Larsen Bay, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-155.3354, 56.8489, 73.8]},
#    'id': 'ak019fe7n163'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.8,
#     'place': '72km WSW of Cantwell, Alaska',
#     'time': 1575198449073,
#     'updated': 1575198852439,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019fe7mlbk',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019fe7mlbk.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 50,
#     'net': 'ak',
#     'code': '019fe7mlbk',
#     'ids': ',ak019fe7mlbk,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.69,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.8 - 72km WSW of Cantwell, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-150.2493, 63.1079, 0]},
#    'id': 'ak019fe7mlbk'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.22,
#     'place': '1km SSW of Round Valley, CA',
#     'time': 1575198149410,
#     'updated': 1575517922906,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc73310616',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/nc73310616.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 23,
#     'net': 'nc',
#     'code': '73310616',
#     'ids': ',nn00712185,nc73310616,',
#     'sources': ',nn,nc,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 13,
#     'dmin': 0.2564,
#     'rms': 0.07,
#     'gap': 298,
#     'magType': 'md',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 1km SSW of Round Valley, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-118.6041667, 37.406, 3.88]},
#    'id': 'nc73310616'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.23,
#     'place': '27km NNE of Seeley Lake, Montana',
#     'time': 1575197836070,
#     'updated': 1575213912790,
#     'tz': -420,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/mb80373824',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/mb80373824.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 77,
#     'net': 'mb',
#     'code': '80373824',
#     'ids': ',mb80373824,',
#     'sources': ',mb,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 22,
#     'dmin': 0.192,
#     'rms': 0.15,
#     'gap': 162,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 27km NNE of Seeley Lake, Montana'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-113.3983333, 47.4223333, 16.15]},
#    'id': 'mb80373824'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.2,
#     'place': '21km ESE of Little Lake, CA',
#     'time': 1575196910800,
#     'updated': 1575197134464,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39212912',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39212912.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 22,
#     'net': 'ci',
#     'code': '39212912',
#     'ids': ',ci39212912,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 22,
#     'dmin': 0.079,
#     'rms': 0.18,
#     'gap': 57,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.2 - 21km ESE of Little Lake, CA'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-117.6913333, 35.8603333, 5.74]},
#    'id': 'ci39212912'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.35,
#     'place': '4km SSW of Volcano, Hawaii',
#     'time': 1575196155500,
#     'updated': 1575337511800,
#     'tz': -600,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/hv71257296',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/hv71257296.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 85,
#     'net': 'hv',
#     'code': '71257296',
#     'ids': ',hv71257296,',
#     'sources': ',hv,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': 28,
#     'dmin': 0.009968,
#     'rms': 0.08,
#     'gap': 48,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.4 - 4km SSW of Volcano, Hawaii'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-155.2561667, 19.3946667, 1.68]},
#    'id': 'hv71257296'},
#   {'type': 'Feature',
#    'properties': {'mag': 4.3,
#     'place': '75km NNE of Mundo Nuevo, Mexico',
#     'time': 1575194551033,
#     'updated': 1575195961040,
#     'tz': -360,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us70006ez9',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us70006ez9.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'reviewed',
#     'tsunami': 0,
#     'sig': 284,
#     'net': 'us',
#     'code': '70006ez9',
#     'ids': ',us70006ez9,',
#     'sources': ',us,',
#     'types': ',geoserve,origin,phase-data,',
#     'nst': None,
#     'dmin': 3.608,
#     'rms': 0.99,
#     'gap': 97,
#     'magType': 'mb',
#     'type': 'earthquake',
#     'title': 'M 4.3 - 75km NNE of Mundo Nuevo, Mexico'},
#    'geometry': {'type': 'Point', 'coordinates': [-95.2528, 19.3406, 10]},
#    'id': 'us70006ez9'},
#   {'type': 'Feature',
#    'properties': {'mag': 2.23,
#     'place': '18km S of Trona, CA',
#     'time': 1575194491180,
#     'updated': 1575194716698,
#     'tz': -480,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci39212880',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ci39212880.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 77,
#     'net': 'ci',
#     'code': '39212880',
#     'ids': ',ci39212880,',
#     'sources': ',ci,',
#     'types': ',geoserve,nearby-cities,origin,phase-data,scitech-link,',
#     'nst': 31,
#     'dmin': 0.06439,
#     'rms': 0.2,
#     'gap': 52,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 2.2 - 18km S of Trona, CA'},
#    'geometry': {'type': 'Point', 'coordinates': [-117.3845, 35.5981667, 2.45]},
#    'id': 'ci39212880'},
#   {'type': 'Feature',
#    'properties': {'mag': 1.6,
#     'place': '72km W of Anchor Point, Alaska',
#     'time': 1575194050995,
#     'updated': 1575194789217,
#     'tz': -540,
#     'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak019fe6prwd',
#     'detail': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/ak019fe6prwd.geojson',
#     'felt': None,
#     'cdi': None,
#     'mmi': None,
#     'alert': None,
#     'status': 'automatic',
#     'tsunami': 0,
#     'sig': 39,
#     'net': 'ak',
#     'code': '019fe6prwd',
#     'ids': ',ak019fe6prwd,',
#     'sources': ',ak,',
#     'types': ',geoserve,origin,',
#     'nst': None,
#     'dmin': None,
#     'rms': 0.42,
#     'gap': None,
#     'magType': 'ml',
#     'type': 'earthquake',
#     'title': 'M 1.6 - 72km W of Anchor Point, Alaska'},
#    'geometry': {'type': 'Point', 'coordinates': [-153.1159, 59.8211, 103.8]},
#    'id': 'ak019fe6prwd'},
#   ...],
#  'bbox': [-179.929, -58.5067, -3.19, 179.7852, 69.193, 607.76]}

# %% [markdown]
# ## Reminder of Evaluation Criteria
#
# 1. Was the problem attempted (analysis, code, and answered questions) ?
# 2. Was the problem analysis thought out? (does the program match the plan?)
# 3. Does the code execute without syntax error?
# 4. Does the code solve the intended problem?
# 5. Is the code well written? (easy to understand, modular, and self-documenting, handles errors)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-4c605e76f8cb> in <module>
# ----> 1 data.sample(5)
#
# AttributeError: 'dict' object has no attribute 'sample'
