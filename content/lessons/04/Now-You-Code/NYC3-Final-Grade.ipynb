# %% [markdown]
# # Now You Code 3: Final Grade in IST256
#
# # Part 1
#
# Our Course Syllabus has a grading scale here:
#
# http://ist256.syr.edu/syllabus/#grading-scale
#
# Write a Python program to input a number of points earned out of 600 and then
# outputs the registrar letter grade.
#
# For example:
#
#     IST256 Grade Calculator
#     Enter total points out of 600:  550
#     Grade: A-

# %% [markdown]
# ## Step 1: Problem Analysis
#
# Inputs:
#     - points earned
#
# Outputs:
#     - grade earned
#
# Algorithm (Steps in Program):
#     1. prompt for points earned
#     2. calculate grade = points earned/600
#     3. output grade
#
# Mastery
#             570 - 600	A
#             540 - 569	A-
# Satisfactory
#             510 - 539	B+
#             480 - 509	B
#             450 - 479	B-
# Low Passing
#             420 - 449	C+
#             390 - 419	C
#             360 - 389	C-
# Unsatisfactory
#             300 - 359	D
#             0 - 299	F

# %%
#Step 2: write code here
print ("IST256 Grade Calculator")
grade = int(input("Enter your points earned: "))
if grade >= 0 and grade <= 299:
    print ("Grade: F")
elif grade >= 300 and grade <= 359:
    print ("Grade: D")
elif grade >= 360 and grade <= 389:
    print ("Grade: C-")
elif grade >= 390 and grade <= 419:
    print ("Grade: C")
elif grade >= 420 and grade <= 449:
    print ("Grade: C+")
elif grade >= 450 and grade <= 479:
    print ("Grade: B-")
elif grade >= 480 and grade <= 509:
    print ("Grade: B")
elif grade >= 510 and grade <= 539:
    print ("Grade: B+")
elif grade >= 540 and grade <= 569:
    print ("Grade: A-")
elif grade >= 570:
    print ("Grade: A")
# Out:
# IST256 Grade Calculator
# Enter your points earned: -10

# %% [markdown]
# # Part 2
#
# Now that you have it working,  re-write your code to handle bad input. Specifically:
#
#
# - non integer values
# - integer values outside the 0 to 600 range.
#
# **Note:** Exception handling is not part of our algorithm. It's a programming concern, not a problem-solving concern!

# %%
## Step 2 (again): write code again but handle errors with try...except
try:
    print ("IST256 Grade Calculator")
    grade = int(input("Enter your points earned: "))
    if grade < 0 or grade >600:
        print ("That's not a proper point total")
    elif grade >= 0 and grade <= 299:
        print ("Grade: F")
    elif grade >= 300 and grade <= 359:
        print ("Grade: D")
    elif grade >= 360 and grade <= 389:
        print ("Grade: C-")
    elif grade >= 390 and grade <= 419:
        print ("Grade: C")
    elif grade >= 420 and grade <= 449:
        print ("Grade: C+")
    elif grade >= 450 and grade <= 479:
        print ("Grade: B-")
    elif grade >= 480 and grade <= 509:
        print ("Grade: B")
    elif grade >= 510 and grade <= 539:
        print ("Grade: B+")
    elif grade >= 540 and grade <= 569:
        print ("Grade: A-")
    elif grade >= 570:
        print ("Grade: A")
except ValueError:
        print ("That's not a proper point total.")
# Out:
# IST256 Grade Calculator
# Enter your points earned: jhjkds
# That's not a proper point total.

# %% [markdown]
# ## Step 3: Questions
#
# 1. What specific Python Error are we handling (please provide the name of it)?
#     -ValueError
# 2. How many times must you execute this program and check the output before you canbe reasonably assured your code is correct? Explain.
#     - You need to check it at least 13 times. This is because you need to check each letter grade as well as a negative number, a number higher than 600 and a non integer input.
# 3. When testing this program do you think its more important to test numbers in the middle of the grade range or exactly on the boundary between one grade range and the next. Justify your response.
#         -I think

# %% [markdown]
# ## Reminder of Evaluation Criteria
#
# 1. Was the problem attempted (analysis, code, and answered questions) ?
# 2. Was the problem analysis thought out? (does the program match the plan?)
# 3. Does the code execute without syntax error?
# 4. Does the code solve the intended problem?
# 5. Is the code well written? (easy to understand, modular, and self-documenting, handles errors)
