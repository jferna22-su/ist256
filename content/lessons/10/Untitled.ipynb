# %%
#Create a list called Team_Roster.
team_roster = []

#Add 3 player names to your roster - Pugh, Lloyd, Harris
# Use either team_roster = ["Pugh", "Lloyd", "Harris"] or
team_roster.append ("Pugh")
team_roster.append ("Lloyd")
team_roster.append ("Harris")

#Looks like a list won't cut it. Empty it out!
team_roster = []

#Create a Dictionary called Player. It should be empty.

player = {}

#Get a Player in the Dictionary. Here's what to know.
# Team: Red Stars
# Player_name: Ertz
# Position: Center Back

#player = {"team" : "Red Stars", "player_name" : "Ertz", "position" : "Center Back"}

#use a different mothod to get a player in the dictionary

player["team"] = "Red Stars"
player["player_name"] = "Ertz"
player["position"] = "Center Back"

# Add the player to the Team_roster
team_roster.append(player)

#Print your Roster
print (team_roster)

#Empty out the Player Dictionary so we can add a new one.
#The new player is
# Team: Orlando Pride
# Player_name: Harris
# Position: Keeper

player = {"team" : "Orlando Pride", "player_name" : "Harris", "position" : "Keeper"}

#Add player to roster
team_roster.append(player)

#Print out entire roster nicley one player per line only
#include the team, name and position

#for each_player in team_roster:
    #print(each_player['team'], each_player['player_name'], each_player['position'])

#Yep, add a new player
#Team: Washington Spirit
# Player_name: Pugh
# Position: Forward
# Age: 21

player = {"team" : "Washington Spirit", "player_name" : "Pugh", "position" : "Forward", "age" : 21}

#Add player to the roster

team_roster.append(player)

#print entire roster again inlcuding age

for each_player in team_roster:
    print(each_player['team'], each_player['player_name'], each_player['position'], each_player['age'])
# Out:
# [{'team': 'Red Stars', 'player_name': 'Ertz', 'position': 'Center Back'}]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-b0a72d2c9fdf> in <module>
#      66
#      67 for each_player in team_roster:
# ---> 68     print(each_player['team'], each_player['player_name'], each_player['position'], each_player['age'])
#
# KeyError: 'age'

# %%
#Print only one players name
print (team_roster[1]['player_name'])
# Out:
# Harris

# %%
type(team_roster)
# Out:
# list

# %%
print(team_roster)
# Out:
# [{'team': 'Red Stars', 'player_name': 'Ertz', 'position': 'Center Back'}, {'team': 'Orlando Pride', 'player_name': 'Harris', 'position': 'Keeper'}]
