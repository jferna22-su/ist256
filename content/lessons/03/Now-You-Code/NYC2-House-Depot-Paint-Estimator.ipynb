# %% [markdown]
# # Now You Code 2: House Depot Paint Estimator
#
# The big-box hardware store *House Depot* has contracted you to write an App to estimate the amount of paint required to paint a room. Given that 1 gallon of paint covers 400 square feet, you must output the number of paint cans required to paint a rectangular room.
#
# The program should input:
#
# - the length of the room in feet,
# - the width of the room in feet,
# - the height of the room in feet
#
# The program should output:
#
# - total area to be painted (sum of each of the 4 walls, multiplied by the height of the room)
# - the number of gallons of paint required to paint the room.
#
# Example:
#
# ```
# Enter length of room: 12
# Enter width of room: 14
# Enter height of room: 8
# Total area to be painted: 416.00
# Total gallons of paint requried: 2
# ```
#
# HINT: Use the `math.ceil()` function to round up your number of gallons to the nearest whole number. You cannot sell fractional cans of paint!

# %% [markdown]
# ## Step 1: Problem Analysis
#
# Inputs:
#     - Length of the room
#     - Width of the room
#     - Height of the room
#
# Outputs:
#     - Total area to be painted
#     - Total gallons of paint required
#
# Algorithm (Steps in Program):
#     1. Prompt for length of the room
#     2. Prompt for the width of the room
#     3. Prompt for the height of the room
#     4. Calculate total area of the room. This is (room length * 2) + (room width * 2) then multiple that total by room hieght
#     5. Calculate total gallons of paint required. This is room area divided by 400
#     6. Print total area to be painted
#     7. Print total gallons of paint required

# %%
import math # you need this to use math.ceil(), so we wrote this part of the code for you!!! LEAVE IT HERE!
# Step 2: write code here
room_length = float(input("What is the length of your room in feet? "))
room_width = float(input("What is the width of your room in feet? "))
room_height = float(input("What is the height of your room in feet? "))
room_area = (((room_length * 2) + (room_width * 2)) * (room_height))
total_gallons = math.ceil(room_area / 400)
print ("Total area to be painted: %.2f square feet" % room_area)
print ("Total gallons of paint required: %d" % total_gallons)
# Out:
# What is the length of your room in feet? 21
# What is the width of your room in feet? 21
# What is the height of your room in feet? 10
# Total area to be painted: 840.00 square feet
# Total gallons of paint required: 3

# %% [markdown]
# ## Step 3: Questions
#
# 1. Why does the program still run when you enter a negative number for length?
#     - The program still runs when you enter a negative number because it is still an integer.
# 2. Does the output make sense when you enter a negative length? Why type of error is this?
#     - Yes, because it is still doing the math. This is a logic error.
# 3. Why do we use `math.ceil()` in this program? In other words are you allowed to buy 3.75 gallons of paint?
#     - We use math.ceil() because you can only buy paint by the gallon or quart and not just parts of of them and math.ceil will round it up for us.

# %% [markdown]
# ## Reminder of Evaluation Criteria
#
# 1. Was the problem attempted (analysis, code, and answered questions) ?
# 2. Was the problem analysis thought out? (does the program match the plan?)
# 3. Does the code execute without syntax error?
# 4. Does the code solve the intended problem?
# 5. Is the code well written? (easy to understand, modular, and self-documenting, handles errors)
