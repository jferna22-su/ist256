# %% [markdown]
# # Now You Code 4: Email Harvest Training
#
# Let's teach you how to extract emails from text. This has a variety of applications. The most common being buiding a list of emails for spamming... er, I meant "mass marketing."
#
# The best way to find the emails in the mailbox file is to search for lines in the file that begin with "From: (similar to what we did in the lab). When you find an email write just the email address (not "From:" and the address) to "NYC4-emails.txt", and don't worry about duplicates.
#
# The program should print the number of emails it wrote to the file.
#
# Example Run:
#
# ```
# Wrote 27 emails to NYC4-emails.txt
# ```

# %% [markdown]
# ## Step 1: Problem Analysis
#
# Input: (No user input, but we do read from the file `NYC4-mbox-short.txt`
#
# Output (The number of emails collected from the file, and a new file `NYC4-emails.txt` with one email per line.
#
# Algorithm:
#     - open the NYC$-mbox-short.txt
#     - set file to save to as NYC-emails.txt
#     - start an increment counter
#     - for loop reading through each individual line of the short file
#     - use starts with to identify the emails want
#     - strip the line for white spaces
#     - write into email file NYC4-emails.txt
#     - print how many emails I saved to what file

# %%
## Step 2: Write the code
filename = open("NYC4-mbox-short.txt")
file_to_save = ("NYC4-emails.txt")
count = 0
with open (file_to_save, "w") as outf:
    for line in filename:
        line = line.strip()
        if line.startswith("From: ") :
            email = line.strip("From: ")
            outf.write(email + "\n")
            count = count + 1
print("Wrote %d emails to %s" % (count, file_to_save))
# Out:
# Wrote 27 emails to NYC4-emails.txt

# %%
## Step 3: Write a program to read the emails from NYC4-emails.txt and print them to the console
filename = open("NYC4-emails.txt")
for line in filename:
    line = line.strip()
    print(line)
# Out:
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# zqian@umich.edu
# jlowe@iupui.edu
# zqian@umich.edu
# jlowe@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# gsilver@umich.edu
# gsilver@umich.edu
# zqian@umich.edu
# gsilver@umich.edu
# wagnermr@iupui.edu
# zqian@umich.edu
# antranig@caret.cam.ac.uk
# gopal.ramasammycook@gmail.c
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# louis@media.berkeley.edu
# ay@media.berkeley.edu
# cwen@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu

# %% [markdown]
# ## Step 4: Questions
#
# 1. Does this code actually "detect" emails? How does it find emails in the text?
#  - It doesn'r really "detect" emails. It finds then by finding "from:" and then expecting there to be an email after that.
# 2. Explain how this program can be improved to prompt for an email file at runtime?
#  - you can set a variable that asks for a file name to open and search for emails within. That way you can let the user input any file they have that they want to extract email addresses from.
# 3. Devise an approach to remove duplicate emails from the output file. You don't have to write as code, just explain it.
#  - I would add in code that only appends with new emails. This would scan the save file and only add emails if it is not found in the file.

# %% [markdown]
# ## Reminder of Evaluation Criteria
#
# 1. Was the problem attempted (analysis, code, and answered questions) ?
# 2. Was the problem analysis thought out? (does the program match the plan?)
# 3. Does the code execute without syntax error?
# 4. Does the code solve the intended problem?
# 5. Is the code well written? (easy to understand, modular, and self-documenting, handles errors)
