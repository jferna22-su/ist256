# %% [markdown]
# # In-Class Coding Lab: Scrape NASDAQ Stock Quotes
#
# For this lab we will walk you through scraping stock data from the NASDAQ website: http://www.nasdaq.com/
#
# We will walk you through the process and when you're done you'll be tasked with creating a program which when given an NASDAQ symbol will retrieve the name of the stock, price, and percent change.
#
# While we work through the example, we will use Amazon.com's stock symbol:`amzn`
#
# For a list of NASDAQ stocks to try with the completed program, see here: http://www.cnbc.com/nasdaq-100/
#
#
# ## Our plan
#
# Here's our plan for a given stock symbol, for example `amzn` :
#
# 1. use Requests to get HTML from this page http://www.nasdaq.com/symbol/amzn
# 2. use BeautifulSoup4 to extract data from the site. save the data we extract into a dict
# 3. print the stock info from the dict
#
# We will write each step as its own function below

# %%
import requests
from bs4 import BeautifulSoup
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-3f1fab35c5d6> in <module>
#       1 import requests
# ----> 2 from bs4 import BeautifulSoup
#       3 import time
#
# ModuleNotFoundError: No module named 'bs4'

# %% [markdown]
# ## Use Requests to get HTML
#
# Here's the code:

# %%
symbol = "amzn"
url = 'http://www.nasdaq.com/symbol/' + symbol
response = requests.get(url)
if response.ok:
    print (response.text)
else:
    print ("Error retrieving " + url)
# Out:
# <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
#   <head>
#     <meta charset="utf-8" />
# <meta itemprop="acquia_lift:content_title" content="AMZN" />
# <meta itemprop="acquia_lift:content_type" content="page" />
# <meta itemprop="acquia_lift:page_type" content="content page" />
# <meta itemprop="acquia_lift:context_language" content="en" />
# <meta itemprop="acquia_lift:content_section" content="market-activity/stocks" />
# <meta itemprop="acquia_lift:content_keywords" content="" />
# <meta itemprop="acquia_lift:post_id" content="" />
# <meta itemprop="acquia_lift:content_uuid" content="" />
# <meta itemprop="acquia_lift:published_date" content="" />
# <meta itemprop="acquia_lift:persona" content="" />
# <meta itemprop="acquia_lift:engagement_score" content="1" />
# <meta itemprop="acquia_lift:account_id" content="NASDAQ" />
# <meta itemprop="acquia_lift:site_id" content="nasdaq_prod" />
# <meta itemprop="acquia_lift:contentOrigin" content="" />
# <meta itemprop="acquia_lift:liftAssetsURL" content="https://lift3assets.lift.acquia.com/stable" />
# <meta itemprop="acquia_lift:liftDecisionAPIURL" content="https://us-east-1-decisionapi.lift.acquia.com" />
# <meta itemprop="acquia_lift:authEndpoint" content="https://us-east-1-oauth2.lift.acquia.com/authorize" />
# <meta itemprop="acquia_lift:bootstrapMode" content="auto" />
# <meta itemprop="acquia_lift:contentReplacementMode" content="untrusted" />
# <script src="https://lift3assets.lift.acquia.com/stable/lift.js" async></script>
# <script>window.digitalData = {"pageInstanceID":"production:home:market-activity:stocks:amzn","page":{"pageInfo":{"author":null,"breadcrumbs":["home","market-activity","stocks","amzn"],"destinationURL":"https:\/\/www.nasdaq.com\/market-activity\/stocks\/amzn","entryURL":null,"onsiteSearchResults":null,"onsiteSearchTerm":null,"pageID":"home:market-activity:stocks:amzn","pageName":"amzn","pagePathLevel1":"market-activity","pagePathLevel2":"market-activity:stocks","pagePathLevel3":"market-activity:stocks:amzn","pagePathLevel4":null,"pagePathLevel5":null,"publisher":null,"referringURL":null,"sysEnv":null,"timeStamp":1573494791},"category":{"eventType":null,"pageType":"symbol-page","videoType":null,"primaryCategory":"market-activity","subCategory":"stocks"},"attributes":{"adDisplay":false,"assetClass":["stocks"],"businessUnit":null,"campaignParameters":null,"industry":null,"quoteSymbol":["AMZN"],"region":null,"sponsored":false,"topic":null,"audience":null,"glossaryTerm":null}},"user":[{"segment":{"loginStatus":"guest","registrationStatus":"anonymous","cookieOptIn":true,"termsOptIn":false,"offersOptIn":false,"eloquaOptIn":false}}]};</script>
# <title>Amazon.com, Inc. Common Stock (AMZN) Latest Quotes, Charts &amp; News | Nasdaq</title>
# <meta name="twitter:card" content="summary_large_image" />
# <meta name="twitter:site" content="@Nasdaq" />
# <meta property="og:url" content="https://www.nasdaq.com/market-activity/stocks/amzn" />
# <meta property="og:title" content="AMZN" />
# <meta itemprop="acquia_lift:event_udf13" content="AMZN" />
# <meta itemprop="acquia_lift:event_udf12" content="Stocks" />
# <meta name="com.nasdaq.cms.taxonomy.pageType" content="symbol-page" />
# <meta name="com.nasdaq.cms.taxonomy.quoteSymbol" content="AMZN" />
# <meta itemprop="acquia_lift:event_udf14" content="" />
# <meta name="com.nasdaq.cms.taxonomy.assetClass" content="stocks" />
# <meta name="com.nasdaq.cms.taxonomy.region" content="" />
# <meta name="description" content="Find the latest quotes for (Amazon.com, Inc. Common Stock) (AMZN) as well as charts and news at Nasdaq.com." />
# <meta name="Generator" content="Drupal 8 (https://www.drupal.org)" />
# <meta name="MobileOptimized" content="width" />
# <meta name="HandheldFriendly" content="true" />
# <meta name="viewport" content="width=device-width, initial-scale=1.0" />
# <script>function euCookieComplianceLoadScripts() {}</script>
# <style></style>
# <script type="application/ld+json">{
#     "@context": "https://schema.org",
#     "@graph": [
#         {
#             "@type": "Corporation",
#             "@id": "https://www.nasdaq.com/",
#             "name": "Nasdaq",
#             "url": "https://www.nasdaq.com/",
#             "logo": {
#                 "@type": "ImageObject",
#                 "url": "https://www.nasdaq.com/themes/nsdq/dist/assets/images/logo-half-white.svg"
#             }
#         },
#         {
#             "@type": "WebPage",
#             "breadcrumb": {
#                 "@type": "BreadcrumbList",
#                 "itemListElement": [
#                     {
#                         "@type": "ListItem",
#                         "position": 1,
#                         "name": "Home",
#                         "item": "https://www.nasdaq.com/"
#                     },
#                     {
#                         "@type": "ListItem",
#                         "position": 2,
#                         "name": "Market Activity",
#                         "item": "https://www.nasdaq.com/market-activity"
#                     },
#                     {
#                         "@type": "ListItem",
#                         "position": 3,
#                         "name": "Stocks",
#                         "item": "https://www.nasdaq.com/market-activity/stocks"
#                     }
#                 ]
#             }
#         },
#         {
#             "@type": "WebSite",
#             "name": "Nasdaq",
#             "url": "https://www.nasdaq.com/",
#             "potentialAction": {
#                 "@type": "SearchAction",
#                 "query-input": "required name=search_term_string",
#                 "target": {
#                     "@type": "EntryPoint",
#                     "urlTemplate": "https://www.nasdaq.com/search?q={search_term_string}"
#                 }
#             }
#         }
#     ]
# }</script>
#
# <!-- Load the Index Exchange JavaScript Library -->
# <script async src="//js-sec.indexww.com/ht/p/183702-142296045723403.js"></script>
#
# <script async src="//www.googletagservices.com/tag/js/gpt.js"></script>
# <script type="text/javascript">
# // Initialize the google variables.
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# // Add a place to store the slot name variable.
# googletag.slots = googletag.slots || {};
# // Add a place to store slots that are queued/observed
# // These are slots that we already stored but waiting to be fetched
# googletag.slotsQueued = googletag.slotsQueued || {};
# </script>
#
# <script type="text/javascript">
# //Load the APS JavaScript Library
# !function(a9,a,p,s,t,A,g){if(a[a9])return;function q(c,r){a[a9]._Q.push([c,r])}a[a9]={init:function(){q("i",arguments)},fetchBids:function(){q("f",arguments)},setDisplayBids:function(){},targetingKeys:function(){return[]},_Q:[]};A=p.createElement(s);A.async=!0;A.src=t;g=p.getElementsByTagName(s)[0];g.parentNode.insertBefore(A,g)}("apstag",window,document,"script","//c.amazon-adsystem.com/aax2/apstag.js");
#
# //Initialize the Library
# apstag.init({
#     pubID: '3444',
#     adServer: 'googletag',
#     bidTimeout: 800
# });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [[1, 1], [300, 250]])
#                   .addSize([1024, 0], [[1, 1], [300, 250], [728, 90], [970, 250]])
#                   .addSize([1200, 0], [[1, 1], [728, 90], [970, 250], [1200, 628]])
#                 .build();
#
#     googletag.slots["js-dfp-tag--UA"] = googletag.defineSlot("/3244/market-activity__stocks/BTF_MidPageFullWidth", [[1, 1], [300, 250], [728, 90], [970, 250], [1200, 628]], "js-dfp-tag--UA")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [])
#                   .addSize([1200, 0], [[1, 1], [120, 60]])
#                 .build();
#
#     googletag.slots["js-dfp-tag-c3s"] = googletag.defineSlot("/3244/market-activity__stocks/BTF_FeaturedSymbol3Up_3", [[1, 1], [120, 60]], "js-dfp-tag-c3s")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [])
#                   .addSize([1200, 0], [[1, 1], [120, 60]])
#                 .build();
#
#     googletag.slots["js-dfp-tag-Z5Q"] = googletag.defineSlot("/3244/market-activity__stocks/BTF_FeaturedSymbol3Up_2", [[1, 1], [120, 60]], "js-dfp-tag-Z5Q")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [])
#                   .addSize([1200, 0], [[1, 1], [120, 60]])
#                 .build();
#
#     googletag.slots["js-dfp-tag-YYU"] = googletag.defineSlot("/3244/market-activity__stocks/BTF_FeaturedSymbol3Up_1", [[1, 1], [120, 60]], "js-dfp-tag-YYU")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([1200, 0], [[1, 1], [300, 250], [300, 600]])
#                   .addSize([0, 0], [])
#                 .build();
#
#     googletag.slots["js-dfp-tag-dsw"] = googletag.defineSlot("/3244/market-activity__stocks/BTF_RightRailBox", [[1, 1], [300, 250], [300, 600]], "js-dfp-tag-dsw")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [[1, 1], [300, 250]])
#                   .addSize([1024, 0], [[1, 1], [300, 250], [728, 90]])
#                 .build();
#
#     googletag.slots["js-dfp-tag-2ek"] = googletag.defineSlot("/3244/market-activity__stocks/BTF_MidPageTwoThirdsWidth", [[1, 1], [300, 250], [728, 90]], "js-dfp-tag-2ek")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([1200, 0], [[1, 1], [300, 250], [300, 600]])
#                   .addSize([0, 0], [])
#                 .build();
#
#     googletag.slots["js-dfp-tag-Uxw"] = googletag.defineSlot("/3244/market-activity__stocks/BTF_RightRailBox", [[1, 1], [300, 250], [300, 600]], "js-dfp-tag-Uxw")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [[1, 1], [300, 250]])
#                   .addSize([1024, 0], [[1, 1], [300, 250], [728, 90]])
#                 .build();
#
#     googletag.slots["js-dfp-tag-axA"] = googletag.defineSlot("/3244/market-activity__stocks/BTF_MidPageTwoThirdsWidth", [[1, 1], [300, 250], [728, 90]], "js-dfp-tag-axA")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [[1, 1], [300, 250]])
#                   .addSize([1024, 0], [[1, 1], [300, 250], [728, 90]])
#                 .build();
#
#     googletag.slots["js-dfp-tag-IAo"] = googletag.defineSlot("/3244/market-activity__stocks/BTF_MidPageTwoThirdsWidth", [[1, 1], [300, 250], [728, 90]], "js-dfp-tag-IAo")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([1200, 0], [[1, 1], [300, 250], [300, 600]])
#                   .addSize([0, 0], [])
#                 .build();
#
#     googletag.slots["js-dfp-tag-iEg"] = googletag.defineSlot("/3244/market-activity__stocks/BTF_RightRailBox", [[1, 1], [300, 250], [300, 600]], "js-dfp-tag-iEg")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#
#     googletag.slots["js-dfp-tag-4d4"] = googletag.defineSlot("/3244/market-activity__stocks/ATF_RightRail2UpButton_2", [[88, 31], [120, 60]], "js-dfp-tag-4d4")
#
#         .addService(googletag.pubads())
#
#
#
#
#             ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#
#     googletag.slots["js-dfp-tag-5yE"] = googletag.defineSlot("/3244/market-activity__stocks/ATF_RightRail2UpButton_1", [[88, 31], [120, 60]], "js-dfp-tag-5yE")
#
#         .addService(googletag.pubads())
#
#
#
#
#             ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([1200, 0], [[300, 250], [300, 600]])
#                   .addSize([0, 0], [])
#                 .build();
#
#     googletag.slots["js-dfp-tag-DoY"] = googletag.defineSlot("/3244/market-activity__stocks/ATF_RightRailBox", [[300, 250], [300, 600]], "js-dfp-tag-DoY")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [[1, 1], [300, 250]])
#                   .addSize([1024, 0], [[1, 1], [300, 250], [728, 90]])
#                 .build();
#
#     googletag.slots["js-dfp-tag-mC4"] = googletag.defineSlot("/3244/market-activity__stocks/BTF_MidPageTwoThirdsWidth", [[1, 1], [300, 250], [728, 90]], "js-dfp-tag-mC4")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [[1, 1], [300, 250]])
#                   .addSize([1024, 0], [[1, 1], [300, 250], [728, 90]])
#                 .build();
#
#     googletag.slots["js-dfp-tag-sHA"] = googletag.defineSlot("/3244/market-activity__stocks/BTF_MidPageTwoThirdsWidth", [[1, 1], [300, 250], [728, 90]], "js-dfp-tag-sHA")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#
#     googletag.slots["js-dfp-tag-_Dc"] = googletag.defineSlot("/3244/market-activity__stocks/ATF_Native", 'fluid', "js-dfp-tag-_Dc")
#
#         .addService(googletag.pubads())
#
#
#
#
#             ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#
#     googletag.slots["js-dfp-tag-GAI"] = googletag.defineSlot("/3244/market-activity__stocks/ATF_FindASymbolRight_2", [[1, 1], [88, 31], [120, 60]], "js-dfp-tag-GAI")
#
#         .addService(googletag.pubads())
#
#
#
#
#             ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#
#     googletag.slots["js-dfp-tag-b3w"] = googletag.defineSlot("/3244/market-activity__stocks/ATF_FindASymbolRight_1", [[1, 1], [88, 31], [120, 60]], "js-dfp-tag-b3w")
#
#         .addService(googletag.pubads())
#
#
#
#
#             ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#
#     googletag.slots["js-dfp-tag-3J4"] = googletag.defineSlot("/3244/market-activity__stocks/ATF_FindASymbolLeft_2", [[1, 1], [88, 31], [120, 60]], "js-dfp-tag-3J4")
#
#         .addService(googletag.pubads())
#
#
#
#
#             ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#
#     googletag.slots["js-dfp-tag-h6k"] = googletag.defineSlot("/3244/market-activity__stocks/ATF_FindASymbolLeft_1", [[1, 1], [88, 31], [120, 60]], "js-dfp-tag-h6k")
#
#         .addService(googletag.pubads())
#
#
#
#
#             ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [[1, 1], [320, 50]])
#                   .addSize([768, 0], [728, 90])
#                   .addSize([1200, 0], [[728, 90], [970, 250]])
#                 .build();
#
#     googletag.slots["js-dfp-tag-2rQ"] = googletag.defineSlot("/3244/market-activity__stocks/ATF_Leaderboard", [[1, 1], [320, 50], [728, 90], [970, 250]], "js-dfp-tag-2rQ")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [1, 1])
#                   .addSize([768, 0], [1, 1])
#                   .addSize([1200, 0], [1, 1])
#                 .build();
#
#     googletag.slots["js-dfp-tag-e4k"] = googletag.defineSlot("/3244/market-activity__stocks/ATF_Pixel_3", [1, 1], "js-dfp-tag-e4k")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [1, 1])
#                   .addSize([768, 0], [1, 1])
#                   .addSize([1200, 0], [1, 1])
#                 .build();
#
#     googletag.slots["js-dfp-tag-gVI"] = googletag.defineSlot("/3244/market-activity__stocks/ATF_Pixel_2", [1, 1], "js-dfp-tag-gVI")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#             // Start by defining breakpoints for this ad.
#         var mapping = googletag.sizeMapping()
#                   .addSize([0, 0], [1, 1])
#                   .addSize([768, 0], [1, 1])
#                   .addSize([1200, 0], [1, 1])
#                 .build();
#
#     googletag.slots["js-dfp-tag-DUA"] = googletag.defineSlot("/3244/market-activity__stocks/ATF_Pixel_1", [1, 1], "js-dfp-tag-DUA")
#
#         .addService(googletag.pubads())
#
#
#
#
#               // Apply size mapping when there are breakpoints.
#       .defineSizeMapping(mapping)
#         ;
#   });
# </script>
# <script type="text/javascript">
# googletag.cmd.push(function() {
#       googletag.pubads().enableAsyncRendering();
#         googletag.pubads().enableSingleRequest();
#         googletag.pubads().collapseEmptyDivs();
#         googletag.pubads().disableInitialLoad();
#
#   googletag.pubads().setTargeting("nasdaqdotcom_page_instance_id", digitalData.pageInstanceID || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_page_template", digitalData.page.category.pageType || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_publisher", digitalData.page.pageInfo.publisher || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_region_tag_list", (digitalData.page.attributes.region || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_topic_tag_list", (digitalData.page.attributes.topic || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_asset_class_tag_list", (digitalData.page.attributes.assetClass || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_quote_symbol_list", (digitalData.page.attributes.quoteSymbol || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_industry_tag_list", (digitalData.page.attributes.industry || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_audience_tag_lists", (digitalData.page.attributes.audience || []).join(","));
#   googletag.pubads().setTargeting("nasdaqdotcom_video_type", digitalData.page.category.videoType || '');
#   googletag.pubads().setTargeting("nasdaqdotcom_event_type", digitalData.page.category.eventType || '');
#
#   if (typeof AcquiaLift !== 'undefined' && AcquiaLift.currentSegments) {
#     googletag.pubads().setTargeting("acquialift_segment_id", AcquiaLift.currentSegments.map(function(d){return d.id}).join(",") || "");
#   }
#
#   googletag.pubads().enableLazyLoad({
#     fetchMarginPercent: 500,
#     renderMarginPercent: 200,
#     mobileScaling: 2.0
#   });
#
#   // Load ATF slots only on load
#   // BTF slots should load when first instance enters the viewport (see assets/scripts/ads.js)
#
#   var slotValues = Object.keys(googletag.slots).map(function(e) {
#     return googletag.slots[e]
#   });
#
#   var ATFslots = slotValues.filter(function (slot) {
#     return !/BTF/gi.test(slot.getSlotId().toString());
#   });
#
#   // Store in queue
#   ATFslots.forEach(function (slot) {
#     var slotElementId = slot.getSlotElementId();
#     googletag.slotsQueued[slotElementId] = slot;
#   });
#
#   var amazonSlots = ATFslots.map( function(s) {
#     var slotID = s.getSlotElementId();
#     var slotName = s.getSlotId().toString();
#     var sizes = s.getSizes().map(function(d){return [d.l, d.j]});
#     return {
#      slotID: slotID,
#      slotName: slotName,
#      sizes: sizes
#     }
#   });
#
#   apstag.fetchBids({
#     slots: amazonSlots
#   }, function(bids) {
#     // set apstag targeting on googletag, then trigger the first DFP request in googletag's disableInitialLoad integration
#     googletag.cmd.push(function(){
#         apstag.setDisplayBids();
#         googletag.pubads().refresh(ATFslots);
#     });
#   });
#
#   googletag.enableServices();
#
#   setInterval(function(){
#     googletag.pubads().refresh();
#   },40000);
# });
# </script>
# <link rel="shortcut icon" href="/sites/acquia.prod/files/favicon.ico" type="image/vnd.microsoft.icon" />
# <script src="/sites/acquia.prod/files/google_tag/google_tag.script.js?q0nrpp"></script>
#
#         <link rel="stylesheet" media="all" href="/sites/acquia.prod/files/css/css_gVQS4jxz8fKTMlMQmyp0BG4J2HKmJBvm_OfVh6KJPyw.css?q0nrpp" />
# <link rel="stylesheet" media="all" href="/sites/acquia.prod/files/css/css_AMbYeNEHhsdIvWS5fhsiQlP41YrZYZ7HTUM164cSp7s.css?q0nrpp" />
#
#     <script type="application/json" data-drupal-selector="drupal-settings-json">{"path":{"baseUrl":"\/","scriptPath":null,"pathPrefix":"","currentPath":"nasdaq_symbol\/2873","currentPathIsAdmin":false,"isFront":false,"currentLanguage":"en"},"pluralDelimiter":"\u0003","jquery":{"ui":{"datepicker":{"isRTL":false,"firstDay":0}}},"ajaxPageState":{"libraries":"blazy\/load,core\/html5shiv,core\/picturefill,datalayer\/behaviors,eu_cookie_compliance\/eu_cookie_compliance_bare,lr_ciam\/drupal.ciam_core,lr_ciam\/drupal.ciam_custom,nasdaq_loadmore\/loadmore,nsdq\/ads,nsdq\/arrow-cta,nsdq\/carousel-controls,nsdq\/company-profile,nsdq\/content-feed,nsdq\/dividend-history,nsdq\/earnings-per-share,nsdq\/featured-notification-bar,nsdq\/featured-symbols,nsdq\/find-symbol,nsdq\/footer-form,nsdq\/forecasts,nsdq\/form,nsdq\/global,nsdq\/grid-guides,nsdq\/header-ads,nsdq\/historical-data,nsdq\/inline-card-stack,nsdq\/loader-overlay,nsdq\/modal,nsdq\/module-header,nsdq\/option-chain-tables,nsdq\/picture,nsdq\/predict-walls-treet,nsdq\/quick-links,nsdq\/quote-detail,nsdq\/quote-page-chart,nsdq\/quote-page-jumpnav,nsdq\/quote-press-release,nsdq\/search-overlay,nsdq\/short-interest,nsdq\/sidebar-latest-news,nsdq\/sub-nav,nsdq\/summary-data,nsdq\/svg-loader,nsdq\/symbol-graph,nsdq\/symbol-page-header,nsdq\/symbol-ticker,nsdq\/table-tabs,nsdq\/upgrade-downgrade-b,nsdq\/watchlist,nsdq_admin\/toolbar,paragraphs\/drupal.paragraphs.unpublished,system\/base","theme":"nsdq","theme_token":null},"ajaxTrustedUrl":[],"dataLayer":{"defaultLang":"en","languages":{"en":{"id":"en","name":"English","direction":"ltr","weight":0}}},"ciam":{"verificationUrl":"https:\/\/www.nasdaq.com\/user\/login","resetPasswordUrl":"https:\/\/www.nasdaq.com\/user\/login","loggedIn":false,"accessToken":[],"phoneId":"","appName":"nasdaq","apiKey":"e77a8cb5-d7ad-4ce9-8ae5-6e7524edf5f3","autoHideTime":"","appPath":"\/","callback":"https:\/\/www.nasdaq.com\/user\/ciamlogin?destination=\/market-activity\/stocks\/amzn","home":"https:\/\/www.nasdaq.com\/","sott":"","debugMode":false,"tokenType":"jwt","integrationName":"Nasdaq JWT"},"eu_cookie_compliance":{"popup_enabled":true,"popup_agreed_enabled":false,"popup_hide_agreed":false,"popup_clicking_confirmation":false,"popup_scrolling_confirmation":false,"popup_html_info":"\u003Cdiv class=\u0022eu-cookie-compliance-banner eu-cookie-compliance-banner-info\u0022\u003E\n  \u003Cdiv class=\u0022popup-content info eu-cookie-compliance-content\u0022\u003E\n    \u003Cdiv id=\u0022popup-text\u0022 class=\u0022eu-cookie-compliance-message\u0022\u003E\n      \u003Ch2\u003ESite uses Cookies\u003C\/h2\u003E\n\u003Cp\u003EThis website utilizes cookies and similar technologies for functionality and other purposes including personalization of content. Your use of this website constitutes your acceptance of cookies. To learn more about our cookies and the choices we offer, please see our \u003Ca href=\u0022\/cookie-statement\u0022\u003ECookies Statement\u003C\/a\u003E.\u003C\/p\u003E\n\n              \u003Cbutton type=\u0022button\u0022 class=\u0022find-more-button eu-cookie-compliance-more-button\u0022\u003ECookie policy\u003C\/button\u003E\n          \u003C\/div\u003E\n    \u003Cdiv id=\u0022popup-buttons\u0022 class=\u0022eu-cookie-compliance-buttons\u0022\u003E\n      \u003Cbutton type=\u0022button\u0022 class=\u0022agree-button eu-cookie-compliance-default-button\u0022\u003EOK, got it\u003C\/button\u003E\n          \u003C\/div\u003E\n  \u003C\/div\u003E\n\u003C\/div\u003E","use_mobile_message":false,"mobile_popup_html_info":"\u003Cdiv class=\u0022eu-cookie-compliance-banner eu-cookie-compliance-banner-info\u0022\u003E\n  \u003Cdiv class=\u0022popup-content info eu-cookie-compliance-content\u0022\u003E\n    \u003Cdiv id=\u0022popup-text\u0022 class=\u0022eu-cookie-compliance-message\u0022\u003E\n      \n              \u003Cbutton type=\u0022button\u0022 class=\u0022find-more-button eu-cookie-compliance-more-button\u0022\u003ECookie policy\u003C\/button\u003E\ ...
#
# <!--[if lte IE 8]>
# <script src="/sites/acquia.prod/files/js/js_VtafjXmRvoUgAzqzYTA3Wrjkx9wcWhjP0G4ZnnqRamA.js"></script>
# <![endif]-->
# <script src="/sites/acquia.prod/files/js/js_wiaq1d4FBRVWEFQt81GlA69JcfUiGyTvtRDMf3rvKN4.js"></script>
#
#     <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png">
#     <link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png">
#     <link rel="icon" type="image/png" sizes="16x16" href="/favicon-16x16.png">
#     <link rel="manifest" href="/manifest.json">
#     <meta name="msapplication-TileColor" content="#da532c">
#     <meta name="theme-color" content="#ffffff">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#     <meta name="google-site-verification" content="A4ZdzztVttv1nCpL1SePVC3K2K">
#             <!-- 33Across Header Tag -->
#     <script>if (document.cookie.indexOf('accept-cookies=') == -1) {
#     console.log('No consent yet - Consent box should appear');
#     }
#     else{
#     var Tynt=Tynt||[];Tynt.push('doG6GOFzCr6ykKaKkv7mNO');
#     Tynt.cmd=Tynt.cmd||[];Tynt.cmd.push(function(){
#     Tynt.ads.display('','','inview');});
#     (function(){var h,s=document.createElement('script');
#     s.src=(window.location.protocol==='https:'?
#     'https':'http')+'://cdn.tynt.com/rciv.js';
#     h=document.getElementsByTagName('script')[0];
#     h.parentNode.insertBefore(s,h);})();
#     }</script>
#
#   <script>(window.BOOMR_mq=window.BOOMR_mq||[]).push(["addVar",{"rua.upush":"false","rua.cpush":"false","rua.upre":"false","rua.cpre":"false","rua.uprl":"false","rua.cprl":"false","rua.cprf":"false","rua.trans":"","rua.cook":"false","rua.ims":"false","rua.ufprl":"false","rua.cfprl":"false"}]);</script>
#   <script>!function(){function o(n,i){if(n&&i)for(var r in i)i.hasOwnProperty(r)&&(void 0===n[r]?n[r]=i[r]:n[r].constructor===Object&&i[r].constructor===Object?o(n[r],i[r]):n[r]=i[r])}try{var n=decodeURIComponent("");if(n.length>0&&window.JSON&&"function"==typeof window.JSON.parse){var i=JSON.parse(n);void 0!==window.BOOMR_config?o(window.BOOMR_config,i):window.BOOMR_config=i}}catch(r){window.console&&"function"==typeof window.console.error&&console.error("mPulse: Could not parse configuration",r)}}();</script>
#   <script>!function(e){var a="https://s.go-mpulse.net/boomerang/",t="addEventListener";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,a="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="JMQ95-CD7GZ-6S8JD-G393D-PHU4L",function(){function n(a){e.BOOMR_onload=a&&a.timeStamp||(new Date).getTime()}if(!e.BOOMR||!e.BOOMR.version&&!e.BOOMR.snippetExecuted){e.BOOMR=e.BOOMR||{},e.BOOMR.snippetExecuted=!0;var i,o,r,_=document.createElement("iframe");if(e[t])e[t]("load",n,!1);else if(e.attachEvent)e.attachEvent("onload",n);_.src="javascript:void(0)",_.title="",_.role="presentation",(_.frameElement||_).style.cssText="width:0;height:0;border:0;display:none;",r=document.getElementsByTagName("script")[0],r.parentNode.insertBefore(_,r);try{o=_.contentWindow.document}catch(O){i=document.domain,_.src="javascript:var d=document.open();d.domain='"+i+"';void(0);",o=_.contentWindow.document}o.open()._l=function(){var e=this.createElement("script");if(i)this.domain=i;e.id="boomr-if-as",e.src=a+"JMQ95-CD7GZ-6S8JD-G393D-PHU4L",BOOMR_lstart=(new Date).getTime(),this.body.appendChild(e)},o.write("<bo"+'dy onload="document._l();">'),o.close()}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var a=""=="true"?1:0,t="",n="qdtppedinm2xuxojxcvq-f-f1f2059d7-clientnsv4-s.akamaihd.net",i={"ak.v":25,"ak.cp":"841979","ak.ai":parseInt("537243",10),"ak.ol":"0","ak.cr":16,"ak.ipv":4,"ak.proto":"","ak.rid":"d0847cf","ak.r":26477,"ak.a2":a,"ak.m":"dsca","ak.n":"essl","ak.bpcip":"128.230.247.0","ak.cport":53174,"ak.gh":"23.215.131.20","ak.quicv":"","ak.tlsv":"tls1.2","ak.0rtt":"","ak.csrc":"-","ak.acc":"fast","ak.t":"1573501099"};if(""!==t)i["ak.ruds"]=t;var o={i:!1,av:function(a){var t="http.initiator";if(a&&(!a[t]||"spa_hard"===a[t]))i["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(i)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:i,akDNSPreFetchDomain:n,init:function(){if(!o.i){var e=BOOMR.subscribe;e("before_beacon",o.av,null,null),e("onbeacon",o.rv,null,null),o.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></head>
#   <body class="path-nasdaq-symbol with-header-ads">
#         <a href="#main-content" class="jumpnav">Skip to main content</a>
#     <noscript aria-hidden="true"><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-TB9QCTB&amp;gtm_auth=AbgJsDZWx9ClJu0CVnQWXA&amp;gtm_preview=env-10&amp;gtm_cookies_win=x" height="0" width="0" title="Google Tag Manager"></iframe></noscript>
#       <div class="header-ads">
#     <div class="header-ads__left">
#
#     </div>
#     <div class="header-ads__center">
#       <div class="ads__header-ad-pixel-3-up">
#       <div class="ads__header-ad-pixel-3-up__pixel">
#
# <div id="js-dfp-tag-DUA"  class="atf-pixel-1">
#
#     <script type="text/javascript">
#         googletag.cmd.push(function() {
#             googletag.display('js-dfp-tag-DUA');
#         });
#     </script>
# </div>
#
#     </div>
#       <div class="ads__header-ad-pixel-3-up__pixel">
#
# <div id="js-dfp-tag-gVI"  class="atf-pixel-2">
#
#     <script type="text/javascript">
#         googletag.cmd.push(function() {
#             googletag.display('js-dfp-tag-gVI');
#         });
#     </script>
# </div>
#
#     </div>
#       <div class="ads__header-ad-pixel-3-up__pixel">
#
# <div id="js-dfp-tag-e4k"  class="atf-pixel-3">
#
#     <script type="text/javascript">
#         googletag.cmd.push(function() {
#             googletag.display('js-dfp-tag-e4k');
#         });
#     </script>
# </div>
#
#     </div>
#   </div>
#
#
#       <div class="">
# <div id="js-dfp-tag-2rQ"  class="atf-leaderboard-quotes">
#
#     <script type="text/javascript">
#         googletag.cmd.push(function() {
#             googletag.display('js-dfp-tag-2rQ');
#         });
#     </script>
# </div>
# </div>
#
#
#
#     </div>
#     <div class="header-ads__right">
#
#     </div>
#   </div>
#
#
#       <div class="dialog-off-canvas-main-canvas" data-off-canvas-main-canvas>
#
# <div class="page with-primary-nav with-sub-nav">
#
#   <div class="header-group">
#
#
#
#
# <header class="primary-nav  primary-nav--sticky " data-mega-menu-disabled="FALSE" role="banner">
#   <nav class="primary-nav__content" aria-label="Primary Navigation" role="navigation">
#     <button class="primary-nav__hamburger" aria-label="Toggle mobile navigation menu"></button>
#
#     <div class="primary-nav__logo">
#       <a href="/" title="Nasdaq Homepage">
#         <img class="primary-nav__logo-normal" src="/themes/nsdq/dist/assets/images/logo.svg" alt="Nasdaq Logo" />
#               </a>
#     </div>
#
#     <ul class="primary-nav__links" aria-hidden="true" itemscope itemtype="http://www.schema.org/SiteNavigationElement">
#
#
#
#         <li class="primary-nav__link " itemprop="name">
#           <a class="primary-nav__anchor" data-mega-menu-enabled="true" href="/market-activity" title="" itemprop="url">
#             <span class="primary-nav__anchor-text">Market Activity</span>
#           </a>
#                       <button class="primary-nav__expand" data-enabled="false" aria-label="Market Activity - Click to open sub-navigation">
#               <span class="primary-nav__expand-caret" aria-hidden="true"></span>
#             </button>
#             <div class="primary-nav__mega" aria-hidden="true" >
#   <ul class="primary-nav__mega-list" itemscope itemtype="http://www.schema.org/SiteNavigationElement">
#
#           <li class="primary-nav__mega-column" itemprop="name">
#
#                       <div class="primary-nav__cta" tabindex="0">
#               <a class="primary-nav__cta-link" href="/market-activity" itemprop="url">
#                 <span class="primary-nav__cta-text">See All Market Activity</span>
#                 <span class="primary-nav__cta-arrow" aria-hidden="true"></span>
#               </a>
#             </div>
#
#
#
#
#
#
#                       <span class="primary-nav__header">
#                               <a class="primary-nav__header-link" href="/market-activity" itemprop="url">
#                   <span class="primary-nav__header-link-text">Market Activity</span>
#                   <span class="primary-nav__header-link-caret" aria-hidden="true"></span>
#                 </a>
#                           </span>
#
#
#
#
#
#
#                       <ul class="primary-nav__mega-links" itemscope itemtype="http://www.schema.org/SiteNavigationElement">
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/market-activity/stocks" itemprop="url">Stocks</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/market-activity/funds-and-etfs" itemprop="url">Funds + ETFs</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/market-activity/indexes" itemprop="url">Indexes</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/market-activity/commodities" itemprop="url">Commodities</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/cryptocurrency" itemprop="url">Cryptocurrency</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/currencies" itemprop="url">Currencies</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/market-activity/futures" itemprop="url">Futures</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/fixed-income" itemprop="url">Fixed Income</a>
#                 </li>
#                           </ul>
#
#
#               </li>
#           <li class="primary-nav__mega-column" itemprop="name">
#
#
#                       <span class="primary-nav__header">
#                               Quick Links
#                           </span>
#
#
#
#
#
#
#                       <ul class="primary-nav__mega-links" itemscope itemtype="http://www.schema.org/SiteNavigationElement">
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/quotes/real-time" itemprop="url">Real-Time Quotes</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/market-activity/after-hours" itemprop="url">After-Hours Quotes</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/market-activity/pre-market" itemprop="url">Pre-Market Quotes</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/quotes/Nasdaq-100-Index-Components" itemprop="url">Nasdaq-100</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/stocks/screener" itemprop="url">Symbol Screener</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/market-activity/online-brokers" itemprop="url">Online Brokers</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/glossary" itemprop="url">Glossary</a>
#                 </li>
#                           </ul>
#
#
#               </li>
#           <li class="primary-nav__mega-column" itemprop="name">
#
#
#                       <span class="primary-nav__header">
#                               Market Events
#                           </span>
#
#
#
#
#
#
#                       <ul class="primary-nav__mega-links" itemscope itemtype="http://www.schema.org/SiteNavigationElement">
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/economic-calendar" itemprop="url">Economic Calendar</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/earnings" itemprop="url">Earnings</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/ipos" itemprop="url">IPO Calendar</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/dividends" itemprop="url">Dividends</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/market-activity/stock-splits" itemprop="url">Stock Splits</a>
#                 </li>
#                           </ul>
#
#
#               </li>
#       </ul>
#
#   </div>
#                   </li>
#
#
#
#         <li class="primary-nav__link " itemprop="name">
#           <a class="primary-nav__anchor" data-mega-menu-enabled="true" href="/news-and-insights" title="" itemprop="url">
#             <span class="primary-nav__anchor-text">News + Insights</span>
#           </a>
#                       <button class="primary-nav__expand" data-enabled="false" aria-label="News + Insights - Click to open sub-navigation">
#               <span class="primary-nav__expand-caret" aria-hidden="true"></span>
#             </button>
#             <div class="primary-nav__mega" aria-hidden="true" >
#   <ul class="primary-nav__mega-list" itemscope itemtype="http://www.schema.org/SiteNavigationElement">
#
#           <li class="primary-nav__mega-column" itemprop="name">
#
#                       <div class="primary-nav__cta" tabindex="0">
#               <a class="primary-nav__cta-link" href="/news-and-insights" itemprop="url">
#                 <span class="primary-nav__cta-text">See All News + Insights</span>
#                 <span class="primary-nav__cta-arrow" aria-hidden="true"></span>
#               </a>
#             </div>
#
#
#
#
#
#
#
#
#                       <ul class="primary-nav__mega-subnav" itemscope itemtype="http://www.schema.org/SiteNavigationElement">
#                               <li class="primary-nav__mega-subnav-item" itemprop="name">
#                   <a class="primary-nav__mega-subnav-link" href="/news-and-insights/markets" itemprop="url">Markets</a>
#                 </li>
#                               <li class="primary-nav__mega-subnav-item" itemprop="name">
#                   <a class="primary-nav__mega-subnav-link" href="/news-and-insights/company-intel" itemprop="url">Companies</a>
#                 </li>
#                               <li class="primary-nav__mega-subnav-item" itemprop="name">
#                   <a class="primary-nav__mega-subnav-link" href="/news-and-insights/technology" itemprop="url">Technology</a>
#                 </li>
#                               <li class="primary-nav__mega-subnav-item" itemprop="name">
#                   <a class="primary-nav__mega-subnav-link" href="/news-and-insights/personal-finance" itemprop="url">Personal Finance</a>
#                 </li>
#                               <li class="primary-nav__mega-subnav-item" itemprop="name">
#                   <a class="primary-nav__mega-subnav-link" href="https://www.nasdaq.com/news-and-insights/financial-advisors" itemprop="url">Financial Advisors</a>
#                 </li>
#                           </ul>
#
#               </li>
#           <li class="primary-nav__mega-column" itemprop="name">
#
#
#                       <span class="primary-nav__header">
#                               Topics
#                           </span>
#
#
#
#
#
#
#                       <ul class="primary-nav__mega-links" itemscope itemtype="http://www.schema.org/SiteNavigationElement">
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/news-and-insights/topic/technology/blockchain" itemprop="url">Blockchain</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/news-and-insights/topic/markets/commodities" itemprop="url">Commodities</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/news-and-insights/topic/markets/cryptocurrencies" itemprop="url">Cryptocurrencies</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="https://www.nasdaq.com/news-and-insights/topic/companies/earnings" itemprop="url">Earnings</a>
#                 </li>
#                               <li class="primary-nav__mega-links-item" itemprop="name">
#                   <a class="primary-nav__mega-links-link" href="/news-and-insights/governance-center" itemprop="url">Governance</a>
# ...
# </div>
#
#
#
#             <div class="footer__form-success">
#               <span class="footer__form-success-check"></span>
#               Thanks for submitting!
#             </div>
#           </div>
#         </fieldset>
#       </div>
#
#     <div class="footer__links">
#       <ul class="footer__links-primary">
#                   <li class="footer__link-primary">
#             <a href="http://ir.nasdaq.com/" title="Nasdaq Investor Relations Information">
#               Investor Relations
#             </a>
#           </li>
#                   <li class="footer__link-primary">
#             <a href="/contact-us" title="Contact Nasdaq">
#               Contact
#             </a>
#           </li>
#                   <li class="footer__link-primary">
#             <a href="/about/careers" title="Careers at Nasdaq">
#               Careers
#             </a>
#           </li>
#                   <li class="footer__link-primary">
#             <a href="/mediakit" title="">
#               Advertise
#             </a>
#           </li>
#                   <li class="footer__link-primary">
#             <a href="/marketsite" title="">
#               Nasdaq MarketSIte
#             </a>
#           </li>
#                   <li class="footer__link-primary">
#             <a href="/trust-center" title="">
#               Trust Center
#             </a>
#           </li>
#               </ul>
#
#       <ul class="footer__links-secondary">
#                   <li class="footer__link-secondary">
#             <a href="/privacy-statement" title="">
#               Privacy
#             </a>
#           </li>
#                   <li class="footer__link-secondary">
#             <a href="/cookie-statement" title="">
#               Cookies
#             </a>
#           </li>
#                   <li class="footer__link-secondary">
#             <a href="/legal" title="">
#               Legal
#             </a>
#           </li>
#               </ul>
#     </div>
#
#     <ul class="footer__links-social">
#               <li class="footer__link-social">
#           <a href="https://www.facebook.com/Nasdaq/" title="Visit NASDAQ on Facebook" aria-label="Facebook"></a>
#         </li>
#               <li class="footer__link-social">
#           <a href="https://twitter.com/Nasdaq" title="Visit NASDAQ on Twitter" aria-label="Twitter"></a>
#         </li>
#               <li class="footer__link-social">
#           <a href="https://www.linkedin.com/company/nasdaq/" title="Visit NASDAQ on LinkedIn" aria-label="LinkedIn"></a>
#         </li>
#               <li class="footer__link-social">
#           <a href="https://www.instagram.com/nasdaq" title="Visit NASDAQ on Instagram" aria-label="Instagram"></a>
#         </li>
#               <li class="footer__link-social">
#           <a href="https://www.pinterest.com/nasdaq/" title="Visit NASDAQ on Pinterest" aria-label="Pinterest"></a>
#         </li>
#           </ul>
#
#     <a href="/" class="footer__logo">
#       <img src="/themes/nsdq/dist/assets/images/logo-half-white.svg" alt="Nasdaq Logo" />
#     </a>
#
#     <p class="footer__legal">&copy; 2019, Nasdaq, Inc. All Rights Reserved.</p>
#   </div>
# </footer>
#
#
#
#
#
#
#
#     </footer>
#
#       <section class="watchlist" data-initial-open="false">
#   <button class="watchlist__button" aria-label="Open Watchlist">
#     <span class="watchlist__button-icon" aria-hidden="true"></span>
#     <span class="watchlist__button-text">Watchlist</span>
#     <div class="watchlist__button-toggle" aria-hidden="true"></div>
#   </button>
#
#   <div class="watchlist__content" aria-hidden="true">
#     <header class="watchlist__content-header">
#       <button class="watchlist__add" aria-label="Add a Symbol">Add a Symbol</button>
#       <a href="https://portfolio.nasdaq.com" class="watchlist__portfolio">My Portfolio</a>
#       <button class="watchlist__close" aria-label="Close Watchlist"></button>
#       <button class="watchlist__edit" aria-label="Edit Watchlist">Edit</button>
#     </header>
#
#     <div class="watchlist__symbols">
#
#       <div class="watchlist__glide glide">
#
#
#
# <div class="carousel-controls" data-glide-el="controls">
#   <div class="carousel-controls__prev" data-glide-dir="<">
#
#
#
#
#
#
#   <button class="arrow-cta" aria-label="Previous">
#
#   <span class="arrow-cta__text" aria-label=""></span>
#   <span class="arrow-cta__icon" aria-hidden="true"></span>
#
#   </button>
#
#
#   </div>
#
#   <div class="carousel-controls__count" data-glide-el="count">
#     <span class="carousel-controls__current" data-glide-el="current"></span>/<span class="carousel-controls__total" data-glide-el="total"></span>
#   </div>
#
#   <div class="carousel-controls__next" data-glide-dir=">">
#
#
#
#
#
#
#   <button class="arrow-cta" aria-label="Next">
#
#   <span class="arrow-cta__text" aria-label=""></span>
#   <span class="arrow-cta__icon" aria-hidden="true"></span>
#
#   </button>
#
#
#   </div>
# </div>
#
#
#
#         <div class="watchlist__track glide__track" data-glide-el="track">
#           <ul class="watchlist__slides glide__slides">
#
#             <li class="watchlist__slide glide__slide watchlist__slide--add">
#               <button aria-label="Add a Symbol"></button>
#             </li>
#
#                         <li class="watchlist__slide glide__slide watchlist__slide--clone" aria-hidden="true">
#               <button class="watchlist__slide-remove" aria-hidden="true" aria-label="Remove from Watchlist"></button>
#               <span class="watchlist__slide-icon" aria-hidden="true"></span>
#               <a class="watchlist__slide-link">
#                 <span class="watchlist__slide-name"></span>
#                 <p class="watchlist__slide-price"></p>
#                 <p class="watchlist__slide-change-container">
#                   <span class="watchlist__slide-change"></span>
#                   <span class="watchlist__slide-change-percent"></span>
#                 <p>
#               </a>
#               <div class="watchlist__slide-overlay" aria-hidden="true"></div>
#             </li>
#                       </ul>
#         </div>
#       </div>
#     </div>
#
#     <div class="watchlist__empty" aria-hidden="true">
#       <span class="watchlist__empty-text">Your Watchlist is empty.</span>
#       <button class="watchlist__empty-add" aria-label="Add a Symbol">Add a Symbol</button>
#       <button class="watchlist__empty-close" aria-label="Close Watchlist"></button>
#     </div>
#
#     <div class="watchlist__loader" aria-hidden="true">
#
#
#
#
# <div class="svg-loader" style="width: 120px;">
#   <div class="svg-loader__container">
#     <svg version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px"
#     viewBox="0 0 70 60" xml:space="preserve">
#       <style type="text/css">
#         .st0 {
#           fill: #0090BA;
#         }
#       </style>
#       <defs>
#         <linearGradient id="mask-gradient-1665849700" gradientUnits="userSpaceOnUse" x2="0" y2="100%">
#           <stop offset="10%" stop-color="white" stop-opacity="0" />
#           <stop offset="20%" stop-color="white" stop-opacity="1" />
#           <stop offset="100%" stop-color="white" stop-opacity="1" />
#           <stop offset="110%" stop-color="white" stop-opacity="0" />
#         </linearGradient>
#         <linearGradient id="mask-gradient-1539557190" gradientUnits="userSpaceOnUse" x2="0" y2="100%">
#           <stop offset="20%" stop-color="white" stop-opacity="0" />
#           <stop offset="25%" stop-color="white" stop-opacity="1" />
#           <stop offset="75%" stop-color="white" stop-opacity="1" />
#           <stop offset="80%" stop-color="white" stop-opacity="0" />
#         </linearGradient>
#         <linearGradient id="mask-gradient-1380935137" gradientUnits="userSpaceOnUse" x2="0" y2="100%">
#           <stop offset="-10%" stop-color="white" stop-opacity="0" />
#           <stop offset="0%" stop-color="white" stop-opacity="1" />
#           <stop offset="80%" stop-color="white" stop-opacity="1" />
#           <stop offset="90%" stop-color="white" stop-opacity="0" />
#         </linearGradient>
#         <mask id="mask-1665849700">
#           <rect class="rect-mask__first" x="0" y="-1" width="35" height="75" fill="url(#mask-gradient-1665849700)" />
#         </mask>
#         <mask id="mask-1539557190">
#           <rect class="rect-mask__second" x="27" y="10" width="16" height="40" fill="url(#mask-gradient-1539557190)" />
#         </mask>
#         <mask id="mask-1380935137">
#           <rect class="rect-mask__third" x="35" y="-10" width="35" height="75" fill="url(#mask-gradient-1380935137)" />
#         </mask>
#       </defs>
#       <path class="st0" mask="url(#mask-1665849700)" d="M34.9,14.9L34.9,14.9c-1.2,0.1-2.3,0.9-2.7,2L16.7,59.6H0l15.5-42.7c0.4-1.1,1.5-2,2.8-2H34.9"/>
#       <path class="st0" mask="url(#mask-1539557190)" d="M33.6,44c-1.2,0-2.1-0.7-2.6-1.7l-3.3-9.2l5.7-15.7c0.1-0.3,0.3-0.6,0.4-0.7c0.5-0.7,1.3-1.2,2.3-1.2
#   c1.2,0,2.2,0.7,2.6,1.7l3.3,9.1l-5.7,15.7c-0.1,0.4-0.3,0.6-0.4,0.7C35.4,43.5,34.6,44,33.6,44z"/>
#       <path class="st0" mask="url(#mask-1380935137)" d="M35,44.6L35,44.6c1.2-0.1,2.1-0.9,2.5-2L53,0h16.7L54.1,42.7c-0.4,1.1-1.5,2-2.8,2H35"/>
#
#     </svg>
#   </div>
# </div>
#
#
#     </div>
#   </div>
# </section>
#
# <section class="watchlist-add-overlay" aria-hidden="true">
#   <div class="watchlist-add-overlay__content">
#     <header class="watchlist-add-overlay__header">
#       <button class="watchlist-add-overlay__back" aria-label="Back"><span class="watchlist-add-overlay__back-text">Back</span></button>
#       <button class="watchlist-add-overlay__close" aria-label="Close Watchlist"></button>
#     </header>
#
#     <form class="watchlist-add-overlay__form">
#       <label class="watchlist-add-overlay__label">Add a symbol to your watchlist</label>
#       <div class="watchlist-add-overlay__input-wrapper">
#         <input class="watchlist-add-overlay__input" placeholder="Enter Symbol">
#       </div>
#     </form>
#
#     <div class="watchlist-add-overlay__unavailable">
#       <button class="watchlist-add-overlay__unavailable-close"></button>
#       <span class="watchlist-add-overlay__unavailable-text"></span>
#     </div>
#
#     <div class="watchlist-add-overlay__results watchlist-add-overlay__results">
#       <header class="watchlist-add-overlay__results-header">Most Active</header>
#       <ul class="watchlist-add-overlay__results-items"></ul>
#                         <li class="watchlist-add-overlay__results-item watchlist-add-overlay__results-item--clone" aria-hidden="true">
#         <span class="watchlist-add-overlay__symbol"></span>
#         <span class="watchlist-add-overlay__name"></span>
#         <button class="watchlist-add-overlay__add" aria-label="Add to Watchlist" data-symbol=""></button>
#       </li>
#
#       <div class="watchlist-add-overlay__loader" aria-hidden="true">
#
#
#
#
# <div class="svg-loader" style="width: 120px;">
#   <div class="svg-loader__container">
#     <svg version="1.1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px"
#     viewBox="0 0 70 60" xml:space="preserve">
#       <style type="text/css">
#         .st0 {
#           fill: #0090BA;
#         }
#       </style>
#       <defs>
#         <linearGradient id="mask-gradient-830112017" gradientUnits="userSpaceOnUse" x2="0" y2="100%">
#           <stop offset="10%" stop-color="white" stop-opacity="0" />
#           <stop offset="20%" stop-color="white" stop-opacity="1" />
#           <stop offset="100%" stop-color="white" stop-opacity="1" />
#           <stop offset="110%" stop-color="white" stop-opacity="0" />
#         </linearGradient>
#         <linearGradient id="mask-gradient-277116240" gradientUnits="userSpaceOnUse" x2="0" y2="100%">
#           <stop offset="20%" stop-color="white" stop-opacity="0" />
#           <stop offset="25%" stop-color="white" stop-opacity="1" />
#           <stop offset="75%" stop-color="white" stop-opacity="1" />
#           <stop offset="80%" stop-color="white" stop-opacity="0" />
#         </linearGradient>
#         <linearGradient id="mask-gradient-1163186896" gradientUnits="userSpaceOnUse" x2="0" y2="100%">
#           <stop offset="-10%" stop-color="white" stop-opacity="0" />
#           <stop offset="0%" stop-color="white" stop-opacity="1" />
#           <stop offset="80%" stop-color="white" stop-opacity="1" />
#           <stop offset="90%" stop-color="white" stop-opacity="0" />
#         </linearGradient>
#         <mask id="mask-830112017">
#           <rect class="rect-mask__first" x="0" y="-1" width="35" height="75" fill="url(#mask-gradient-830112017)" />
#         </mask>
#         <mask id="mask-277116240">
#           <rect class="rect-mask__second" x="27" y="10" width="16" height="40" fill="url(#mask-gradient-277116240)" />
#         </mask>
#         <mask id="mask-1163186896">
#           <rect class="rect-mask__third" x="35" y="-10" width="35" height="75" fill="url(#mask-gradient-1163186896)" />
#         </mask>
#       </defs>
#       <path class="st0" mask="url(#mask-830112017)" d="M34.9,14.9L34.9,14.9c-1.2,0.1-2.3,0.9-2.7,2L16.7,59.6H0l15.5-42.7c0.4-1.1,1.5-2,2.8-2H34.9"/>
#       <path class="st0" mask="url(#mask-277116240)" d="M33.6,44c-1.2,0-2.1-0.7-2.6-1.7l-3.3-9.2l5.7-15.7c0.1-0.3,0.3-0.6,0.4-0.7c0.5-0.7,1.3-1.2,2.3-1.2
#   c1.2,0,2.2,0.7,2.6,1.7l3.3,9.1l-5.7,15.7c-0.1,0.4-0.3,0.6-0.4,0.7C35.4,43.5,34.6,44,33.6,44z"/>
#       <path class="st0" mask="url(#mask-1163186896)" d="M35,44.6L35,44.6c1.2-0.1,2.1-0.9,2.5-2L53,0h16.7L54.1,42.7c-0.4,1.1-1.5,2-2.8,2H35"/>
#
#     </svg>
#   </div>
# </div>
#
#
#       </div>
#     </div>
#   </div>
# </section>
#
# <div class="watchlist-live-region" role="alert" aria-live="assertive" aria-atomic="true" aria-relevant="all"></div>
#
#
#
# </div>
#   </div>
#
#
#     <script src="/sites/acquia.prod/files/js/js_uAQqT23P0_FxDfAGYqmFpHjrpxgyX48wH4J_ZJa9-LE.js"></script>
# <script src="/themes/nsdq/dist/highcharts.js?q0nrpp"></script>
# <script src="/sites/acquia.prod/files/js/js_cVzMBeamRYUaoyqcdZzh2wXlp9Ts7mnhcPTgh7Thp0o.js"></script>
# <script src="https://www.predictwallstreet.com/Widgets/js/widget_v1.1.js"></script>
# <script src="/sites/acquia.prod/files/js/js_cV-4-ML8G11OnlwtSza-BTHeaGZE0HOFO8VJfGprfNA.js"></script>
# <script src="/themes/nsdq/dist/react.vendor.js?q0nrpp"></script>
# <script src="/sites/acquia.prod/files/js/js_yynQT_GYtmyjajqSkgoxCUklI-NGlwqFtDa7S4vuzXo.js"></script>
#
#     <div class="grid-guides">
#   <div class="grid-guides__container">
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#     <div class="grid-guides__row"></div>
#   </div>
# </div>
#
#   </body>
# </html>

# %% [markdown]
# It looks like it works, so we should refactor it into a function and then test again. we pass in the `symbol` as input and return what we would print as output.

# %%
def get_html_from_nasdaq(symbol):
    url = 'http://www.nasdaq.com/symbol/' + symbol
    response = requests.get(url)
    if response.ok:
        return response.text
    else:
        return "Error retrieving " + url

# %% [markdown]
# Let's try it out... should work

# %%
html = get_html_from_nasdaq('amzn')
html
# Out:
# '<!DOCTYPE html>\n<html lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">\n  <head>\n    <meta charset="utf-8" />\n<meta itemprop="acquia_lift:content_title" content="AMZN" />\n<meta itemprop="acquia_lift:content_type" content="page" />\n<meta itemprop="acquia_lift:page_type" content="content page" />\n<meta itemprop="acquia_lift:context_language" content="en" />\n<meta itemprop="acquia_lift:content_section" content="market-activity/stocks" />\n<meta itemprop="acquia_lift:content_keywords" content="" />\n<meta itemprop="acquia_lift:post_id" content="" />\n<meta itemprop="acquia_lift:content_uuid" content="" />\n<meta itemprop="acquia_lift:published_date" content="" />\n<meta itemprop="acquia_lift:persona" content="" />\n<meta itemprop="acquia_lift:engagement_score" content="1" />\n<meta itemprop="acquia_lift:account_id" content="NASDAQ" />\n<meta itemprop="acquia_lift:site_id" content="nasdaq_prod" />\n<meta itemprop="acquia_lift:contentOrigin" content="" />\n<meta itemprop="acquia_lift:liftAssetsURL" content="https://lift3assets.lift.acquia.com/stable" />\n<meta itemprop="acquia_lift:liftDecisionAPIURL" content="https://us-east-1-decisionapi.lift.acquia.com" />\n<meta itemprop="acquia_lift:authEndpoint" content="https://us-east-1-oauth2.lift.acquia.com/authorize" />\n<meta itemprop="acquia_lift:bootstrapMode" content="auto" />\n<meta itemprop="acquia_lift:contentReplacementMode" content="untrusted" />\n<script src="https://lift3assets.lift.acquia.com/stable/lift.js" async></script>\n<script>window.digitalData = {"pageInstanceID":"production:home:market-activity:stocks:amzn","page":{"pageInfo":{"author":null,"breadcrumbs":["home","market-activity","stocks","amzn"],"destinationURL":"https:\\/\\/www.nasdaq.com\\/market-activity\\/stocks\\/amzn","entryURL":null,"onsiteSearchResults":null,"onsiteSearchTerm":null,"pageID":"home:market-activity:stocks:amzn","pageName":"amzn","pagePathLevel1":"market-activity","pagePathLevel2":"market-activity:stocks","pagePathLevel3":"market-activity:stocks:amzn","pagePathLevel4":null,"pagePathLevel5":null,"publisher":null,"referringURL":null,"sysEnv":null,"timeStamp":1573494791},"category":{"eventType":null,"pageType":"symbol-page","videoType":null,"primaryCategory":"market-activity","subCategory":"stocks"},"attributes":{"adDisplay":false,"assetClass":["stocks"],"businessUnit":null,"campaignParameters":null,"industry":null,"quoteSymbol":["AMZN"],"region":null,"sponsored":false,"topic":null,"audience":null,"glossaryTerm":null}},"user":[{"segment":{"loginStatus":"guest","registrationStatus":"anonymous","cookieOptIn":true,"termsOptIn":false,"offersOptIn":false,"eloquaOptIn":false}}]};</script>\n<title>Amazon.com, Inc. Common Stock (AMZN) Latest Quotes, Charts &amp; News | Nasdaq</title>\n<meta name="twitter:card" content="summary_large_image" />\n<meta name="twitter:site" content="@Nasdaq" />\n<meta property="og:url" content="https://www.nasdaq.com/market-activity/stocks/amzn" />\n<meta property="og:title" content="AMZN" />\n<meta itemprop="acquia_lift:event_udf13" content="AMZN" />\n<meta itemprop="acquia_lift:event_udf12" content="Stocks" />\n<meta name="com.nasdaq.cms.taxonomy.pageType" content="symbol-page" />\n<meta name="com.nasdaq.cms.taxonomy.quoteSymbol" content="AMZN" />\n<meta itemprop="acquia_lift:event_udf14" content="" />\n<meta name="com.nasdaq.cms.taxonomy.assetClass" content="stocks" />\n<meta name="com.nasdaq.cms.taxonomy.region" content="" />\n<meta name="description" content="Find the latest quotes for (Amazon.com, Inc. Common Stock) (AMZN) as well as charts and news at Nasdaq.com." />\n<meta name="Generator" content="Drupal 8 (https://www.drup ...

# %% [markdown]
# ## use BeautifulSoup4 to extract data from the site
#
# Next we want to take `html` and extract out the meaningful bits. This is the part that requires time and patience. You'll need to use a browser's developer tools to find the important CSS selectors so you can retrieve the data.
#
# For simplicity's sake, we've done this for you. Feel free to open http://www.nasdaq.com/symbol/amzn in your browser's developer tools and locate each of these three selectors:

# %%
soup = BeautifulSoup(html, "lxml")
name = soup.select("div#qwidget_pageheader h1")[0].text
price = soup.select("div#qwidget_lastsale")[0].text
change = soup.select("div#qwidget_percent")[0].text
print(name,price,change)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4cbac6d88d42> in <module>
# ----> 1 soup = BeautifulSoup(html, "lxml")
#       2 name = soup.select("div#qwidget_pageheader h1")[0].text
#       3 price = soup.select("div#qwidget_lastsale")[0].text
#       4 change = soup.select("div#qwidget_percent")[0].text
#       5 print(name,price,change)
#
# NameError: name 'BeautifulSoup' is not defined

# %% [markdown]
# We can't easily return 3 values from a function (actually you can in python, but we don't like to teach you that) so instead we will create a dictionary of these values first:

# %%
soup = BeautifulSoup(html, "lxml")
name = soup.select("div#qwidget_pageheader h1")[0].text
price = soup.select("div#qwidget_lastsale")[0].text
change = soup.select("div#qwidget_percent")[0].text
stock= { 'Name' : name,
        "Price" : price,
        "Change" : change
}

print(stock)

# %% [markdown]
# Once again, its time to refactor this into a function we take `html` as input (its the one thing we require to make this code work) and `stock` as output (since it is what we print.

# %%
def extract_stock_data(html):
    soup = BeautifulSoup(html, "lxml")
    name = soup.select("div#qwidget_pageheader h1")[0].text
    price = soup.select("div#qwidget_lastsale")[0].text
    change = soup.select("div#qwidget_percent")[0].text
    stock= { 'Name' : name,
            "Price" : price,
            "Change" : change
    }

    return stock

# %% [markdown]
# And we should test out our new function:

# %%
stock = extract_stock_data(html)
print(stock)

# %% [markdown]
# ## Putting it all together
#
# Now you need to put it all together. Write a program to:
#
# 1. input a stock symbol on the NASDAQ exchange
# 2. get the html from the stock symbol on the NASDAQ website
# 3. extract the stock data from the html
# 4. print out the stock informtiom
#
# The program should work like this:
#
# ```
# Enter a stock symbol on the NASDAQ Exchange: amzn
# Name: Amazon.com, Inc. Common Stock Quote & Summary Data
# Price: $852.53
# Change: 0.24%
# ```

# %%
# todo write code here:
