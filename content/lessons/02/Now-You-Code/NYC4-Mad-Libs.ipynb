# %% [markdown]
# # Now You Code 4: Mad Libs!
#
# Write a Python program which creates your own unique Mad-Libs! story.
#
# If you are not familar with a Mad-Libs! story, check out:
# http://www.madlibs.com and http://www.madtakes.com
#
# Your story should take at least 5 inputs, and should include more than
# once sentence.

# %% [markdown]
# ## Step 1: Problem Analysis
#
# Inputs:
# - an adjective
# - a noun
# - a verb
# - another adjective
# - another noun
#
# Outputs:
# - Mad Lib
#
# Algorithm (Steps in Program):
# - input first adjective
# - input first noun
# - input verb
# - input second adjective
# - input second noun
# - print Mad Lib

# %%
# Step 2: Write code here
adjective1 = input("Enter an adjective: ")
noun1 = input("Enter a noun: ")
verb1 = input("Enter a verb: ")
adjective2 = input("Enter another adjective: ")
noun2 = input("Enter another noun: ")
print('')
print('Be nice to your ' + adjective1 + ".")
print('You never know when your ' + noun1 + " will " + verb1 + ".")
print('This is your ' + noun2 + ' not your ' + adjective2 + ".")
# Out:
# Enter an adjective: orange
# Enter a noun: cat
# Enter a verb: eats
# Enter another adjective: black
# Enter another noun: dog
#
# Be nice to your orange.
# You never know when your cat will eats.
# This is your dog not your black.

# %% [markdown]
# ## Step 3: Questions
#
# 1. What happens when you neglect to follow the instructions and enter any inputs we desire? Does the code still run? Why?
# - The code still runs, but it gives you a jumbled output that isn't how it was intended to be. The code still runs because the iputs are proper values.
# 2. What type of error occurs when the program runs but does not handle bad input?
# - Value error
# 3. Is there anything you can do in code to correct this type of error? Why or why not?
# - I do not know if any code to correct this.

# %% [markdown]
# ## Reminder of Evaluation Criteria
#
# 1. Was the problem attempted (analysis, code, and answered questions) ?
# 2. was the problem analysis thought out? (does the program match the plan?)
# 3. Does the code execute without syntax error?
# 4. Does the code solve the intended problem?
# 5. Is the code well written? (easy to understand, modular, and self-documenting, handles errors)
